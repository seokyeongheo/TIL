# %% [markdown]
# #### 0. oauth
# - https://oauth.net/2/
# - 2006년에 IETF(Internet Engineering Task Force) OAuth Working Group에서 개발되고 유지보수 되는 인증을 위한 표준 프로토콜
# - secret key, request token, access token, refresh token
# - https://confluence.atlassian.com/bitbucket/oauth-endpoint-300220600.html

# %% [markdown]
# #### 1. Install Package
# - mac
#     - `$ pip install pygsheets oauth2client`
# - windows
#     - `$ conda install -c marta-sd pygsheets`

# %% [markdown]
# windows에서 아래의 에러가 발생하면 pip로 설치합니다.
# - TypeError: parse() got an unexpected keyword argument 'transport_encoding'
#     - `$ conda install pip`
#     - `$ pip install pygsheets`

# %%
import pandas as pd

# %%
import gc

# %%
gc.collect()
# Out:
# 20

# %%
import pygsheets

# %% [markdown]
# #### 2. authorizing - secret token 받기
# - reference
#     - http://pygsheets.readthedocs.io/en/latest/authorizing.html
#
# 1. 콘솔 페이지로 이동 - https://console.developers.google.com
# 2. 왼쪽 상단의 프로젝트 만들기로 DSS8 프로젝트를 만듦
# 3. 좌측의 라이브러리 탭에서 Google Sheets API, Google Drive API를 추가(사용설정 클릭)
# 4. 사용자 인정 정보 탭으로 이동
# 5. Oauth 동의 화면으로 이동
# 6. 저장 클릭
# 7. 사용자 인증정보 클릭
# 8. Oauth 클라이언트 ID 클릭
# 9. 기타 선택후 dss8로 이름 설정후 확인 클릭
# 10. 우측의 다운로드 버튼 클릭 (json 확장자의 키 파일이 다운로드 된다.)
# 11. 다운로드 받은 파일을 노트북과 같은 디렉토리에 위치하도록 파일을 이동 및 파일이름을 "client_secret.json"으로 변경

# %% [markdown]
# windows에서 아래의 에러가 발생하면 `no_cache = True` 옵션을 설정해 줍니다.
# - FileNotFoundError: [Errno 2] No such file or directory:
#     - gc = pygsheets.authorize(outh_file='client_secret.json', no_cache = True)

# %%
# 아래 코드를 실행하면 auth 인증창이 실행되고 로그인후에 허용을 하면 access_token을 받아온다.
gc = pygsheets.authorize(outh_file='client_secret_922339280762-jdkinmaqsvomrved7711r78jfm6eimed.apps.googleusercontent.com.json', no_cache=True)
gc

# %% [markdown]
# #### 3. open sheet
# - 구글 드라이브로 가서 새로운 시트를 만듭니다.
# - 시트 파일 이름으로 시트를 오픈합니다.
# - open 함수에 시트의 이름을 파라미터로 넣어 구글 드라이버에 있는 시트 파일을 아래와 같이 열수 있습니다.
# - sh로 오픈한 시트 파일의 시트는 sh.sheet1으로 첫번째 시트를 가져올수 있습니다.
# - 처음에는 항상 첫번째 시트를 가져오고 selecting기능으로 다른 시트에 접근할수 있습니다.

# %%
# 아래의 내용을 데이터 시트에 입력
datas = [["박두진", "pdj1224@gmail.com"],
["김상진", "1221pdj@naver.com"],
["최윤성", "pdj1224@daum.net"]]
pd.DataFrame(datas, index=[1,2,3], columns=["이름","이메일"])
# Out:
#     이름                이메일
# 1  박두진  pdj1224@gmail.com
# 2  김상진  1221pdj@naver.com
# 3  최윤성   pdj1224@daum.net

# %%
sh = gc.open('practice_log') # 파일 열기 (sh : 전체 시트에 대한 객체)
sheet1 = sh.sheet1    # 시트 접근 (sheet1 : 첫번째 시트에 대한 객체)
sheet1
# Out:
# <Worksheet 'daily_log' index:0>

# %% [markdown]
# #### 4. create sheet
# - 시트 생성
# - add_worksheet 함수를 이용하여 생성할 시트이름, 행과 열의 크기를 파라미터로 넘겨 새로운 시트를 생성할수 있습니다.

# %%
# 5칸, 20줄을 가지는 new_sheet라는 이름의 새로운 시트를 생성하여 sheet2라는 변수에 넣어줌
sheet2 = sh.add_worksheet("new sheet", rows=20, cols=5)
sheet2
# Out:
# <Worksheet 'new sheet' index:1>

# %% [markdown]
# #### 5. copy sheet
# - 시트 복사
# - add_worksheet를 이용하여 src_worksheet 파라미터에 복사할 시트를 파라미터로 넘기면 새로운 시트를 생성할때 src_worksheet에 설정한 시트가 복사 됩니다.

# %%
# sheet1을 복사하여 email_copied라는 title의 새로운 시트를 생성하여 sheet3이라는 변수에 넣어줌
sheet3 = sh.add_worksheet("email_copied", src_worksheet=sheet1)
sheet3
# Out:
# <Worksheet 'email_copied' index:3>

# %% [markdown]
# #### 6. delete sheet
# - 시트 삭제
# - del_worksheet에 삭제한 시트 객체를 파라미터로 넘기면 해당 시트가 삭제됩니다.

# %%
# sheet3 변수가 가지는 sheet를 삭제
sh.del_worksheet(sheet2)

# %% [markdown]
# #### 7. selecting  sheet
# - 시트가 모여있는 객체인 sh 객체에서 원하는 시트하나에 대한객체를 선택해서 가져오는 방법입니다.
# - 제목과 순서에 대한 값으로 시트를 가져올수 있습니다.

# %%
# 모든 시트 리스트로 가져오기
sheet_list = sh.worksheets()
sheet_list
# Out:
# [<Worksheet '시트1' index:0>,
#  <Worksheet '시트 생성해라!' index:1>,
#  <Worksheet 'new sheet' index:1>]

# %%
# 시트 제목으로 가져오기
new_sheet = sh.worksheet_by_title("new sheet")
print(new_sheet)
# Out:
# <Worksheet 'new sheet' index:1>

# %%
# index로 시트 가져오기
sheet0 = sh.worksheet("index", 1)
print(sheet0)
# Out:
# <Worksheet 'new sheet' index:1>

# %%
# 위에 저장한 첫번째 시트인 sheet1과 같은지 확인하기
sheet0 == sheet2
# Out:
# True

# %%
# offset으로 가져오기
sheet0 = sh[0]
print(sheet0)
# Out:
# <Worksheet '시트1' index:0>

# %%
# 위에 저장한 첫번째 시트인 sheet1과 같은지 확인하기
sheet0 == sheet1
# Out:
# True

# %% [markdown]
# #### 8. get values

# %%
# 전체 데이터 리스트로 가져오기 (딕셔너리타입)
sheet1.get_all_records()
# Out:
# [{},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {},
#  {}]

# %%
# rows와 columns 크기 설정
sh[0].rows = 4
sh[0].cols = 3

# %%
# 모든 데이터 행렬로 가져오기 (리스트타입)
all_data_sheet1 = sheet1.get_all_values(returnas='matrix')
all_data_sheet1
# Out:
# [['', '', '', '', '', ''],
#  [' ', '', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['', '', 'ACT', 'PLAN', 'EVALUATE', 'REFLECT'],
#  ['36',
#   'TOTAL',
#   '',
#   'HOW : 기본 다지기\n\n1.테크 블로그 운영. \n알고리즘, 수리통계학 개념을 실제로 활용하기 위해서 매 수업 내용을 글(포스팅)으로 정리한다.\n\n(i) 수학 (선형대수)\n- KOCW 선형대수 (하루 2개씩 빠르게 듣기) 1주 10개씩. \n- 3B1B 강의, 코딩 더 매트릭스 참고\n\n(ii) 프로그래밍 (알고리즘)\n- 알고리즘 교재 사용 (매일 챕터 조금씩)\n- 프로그래머스 문제 풀이 (하루에 알고리즘 문제 하나씩)\n- 두진강사님 퀴즈 풀이 (할 수 있으면 시도)\n\n\n2.교육, 학습 분석 강의 듣기 \n\n(i) Leaders Of Learning Section2 수강 \n하루에 2 part씩. \nSection2\n  Modes of Leadershiop Intro & Self-Reflection\n  Quadrant1\n  Quadrant2\n  Quadrant3\n  Quadrant4\n  Conclusion check for understanding\n\nSection3\n  Modes of Organization Intro & Self-Reflection\n  Quadrant1\n  Quadrant2\n  Quadrant3\n  Quadrant4\n  Conclusion check for understanding\n\n3.회고\n매일 자기 전 스크럼 작성\n수강생 스크럼 피드백',
#   '',
#   ''],
#  ['', '180827\n\nMON', '스크럼 정리 \n업무 ', '-', '-', '-'],
#  ['',
#   '180828\n\nTUE',
#   '1. LOL Section1 quadrant 1,2 수강 \nModes of Leadershiop Intro & Self-Reflection\nQuadrant1\nQuadrant2\n\n2. 피보나치킨, 알고리즘 level 1 1910-2000 1.5문제 풀이',
#   '1. LOL Section2 quadrant 1,2 수강 \n2. 피보나치킨, (지금까지) 과제 풀이, 알고리즘 level 2 \n3. KOCW 강의 듣기 1, 2강',
#   '1.\nLOL 강의는 빠르게 치고 넘어갈 수 있도록. \n클매 업무를 잘하는 것 자체가 나에게 의미 있지 않다. 클래스매니저는 어차피 거쳐가는, 그리고 노동을 임금으로 교환하는 자리이다. 해당 업무를 너무 잘하려고 많은 시간을 할애하지는 말자. 물론 나와 니즈가 맞는다면, 더 많은 시간을 투자할 만하다.\n\n2.수강생 눈높이에서 모든 내용(수학, 플밍)을 훑을 수는 없다. 나에게도, 수강생에도 서로 좋지 않다. 차라리, 수강생이 짚기 어려운, 핵심적이면서도 깊은 내용을 내가 습득하는게 서로에게 이득이다.\n\n',
#   '1.핵심 수학 내용 KOCW 부분만 숙지(지난 과정 때 듣지 못한 부분+a(원서 교재, 코딩더매트릭스))\n\n2.(나를 위한) 업무 시간을 단축할 수 있는 프로그램 구축. \n- 데일리스크럼 작성 여부 확인 \n> 구글시트 텍스트 크롤링(혹은 구글시트 연동) > 특정 수강생이 데일리스크럼을 작성하지 않으면 슬랙봇으로 알림(inner)\n'],
#  ['',
#   '180829\n\nWED',
#   '',
#   '1. LOL Section2 quadrant3,4 수강 \n2. 피보나치킨, 알고리즘 level2 문제 풀이 \n3. KOCW 14, 15강 수강',
#   '',
#   ''],
#  ['', '180830\n\nTHU', '', '', '', ''],
#  ['', '180831\n\nFRI', '', '', '', ''],
#  ['', '180901\n\nSAT', '', '', '', ''],
#  ['', '180902\n\nSUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['35',
#   'TOTAL',
#   '1.테크 블로그 운영\nhexo 테크 블로그 수정 \n테마 바꾸기(테마는 유지) X, 배너 변경\nMathJax 수식 넣기\n\n2.개인프로젝트 \n높은 빈도 명사 추출\n\n3.edX Leaders Of Learning\nIntro 1935-2045 \nSection1 1545-1620',
#   'HOW : 기본 다지기\n\n1.테크 블로그 운영. 알고리즘, 수리통계학 개념을 실제로 활용하기 위해서 매 수업 내용을 글(포스팅)으로 정리한다.\n- 프로그래머스 알고리즘 문제 풀이 \n\n2.수학 강의 듣기\n- 3~5주차 대비 KOCW 선형대수 14~17강, 교재 풀기 (3B1B 강의, 코딩 더 매트릭스 참고)\n\n3.개인 프로젝트\n매일 조금이라도 시간을 할애한다.(10분~)\n\n4.회고\n매일 일과 마무리 때 회고. 일과 후에는 하지 않는다.',
#   '1. 업무 중 틈틈히 개인 프로젝트 작업은 가능하다. -> 개인 프로젝트 잠정적 중단. 더는 니즈가 있지 않기 때문. 사설 텍스트 분석보다 교육 데이터 분석을 먼저 하고 싶다.\n\n2. 강의(KOCW, edX)는 업무 후 진행해야 한다. 업무 후 공부하기 위해서는 체력이 뒷받침 되어야 한다.',
#   '1.개인 프로젝트 중단. \n수강생 수업, edX(LOL, LA) 수강, 관련 프로젝트 진행 예정.\n\n2.수업(수학, 플밍) 내용 테크 블로그 구축\n박사님 수업 중심으로 헥소 블로그에 정리\nKOCW 선형대수, 3B1B, 코딩더매트릭스 참고 \n\n3.회고'],
#  ['', '180820\n\nMON', '-', '업무', '-', '-'],
#  ['',
#   '180821\n\nTUE',
#   'hexo 테크 블로그 수정 \n테마 바꾸기(테마는 유지) X, 배너 변경\nMathJax 수식 넣기\n\n개인프로젝트 \n높은 빈도 명사 추출\n\nLOL-intro 1935-2045',
#   '3H\n\n1.edx Leaders of Learning _ introduction\n2.KOCW 14강\n3.hexo 테크 블로그 수정 \n테마 바꾸기\n카테고리 생성(선형대수, 최적화, 확률론, 파이썬 등)\n\n*개인 프로젝트 진행 (~30분)\n높은 빈도수 columns 취합',
#   '업무 중 틈틈히 개인 프로젝트 작업은 가능하다.\n\n강의(KOCW, edX)는 업무 후 진행해야 한다. 업무 후 공부하기 위해서는 체력이 뒷받침 되어야 한다.',
#   ''],
#  ['',
#   '180822\n\nWED',
#   'edx 1강 1545-1620',
#   '1.hexo 블로그 글 작성 _ 데사를 위해서 수학 공부를 어떻게 해야 하는가. \n2.edX section1 수강 \n3.개인 프로젝트 진행',
#   '1. 개인 프로젝트 잠정적 중단. 더는 니즈가 있지 않기 때문. 사설 텍스트 분석보다 교육 데이터 분석을 먼저 하고 싶다.\n\n2.',
#   ''],
#  ['', '180823\n\nTHU', '', '데사스 수료', '', ''],
#  ['',
#   '180824\n\nFRI',
#   '',
#   '데이터사이언스스쿨 회고 \nLearning Analytics 프로젝트 열기',
#   '',
#   ''],
#  ['', '180825\n\nSAT', '-', '-', '-', '-'],
#  ['', '180826\n\nSUN', '-', '-', '-', '-'],
#  ['', '', '', '', '', ''],
#  ['34',
#   'TOTAL',
#   '',
#   'HOW : 실전을 위한 시행착오 시간 늘이기(강의노트 정리, 프로젝트 모두)\n\n1.(스터디) 개념을 실제로 활용하기 위해서, 분류 강의노트를 직접 쓰고 코딩한다.(쥬피터 노트북으로 정리)\n\n2.(프로젝트) 개인 프로젝트에 더 많은 시간을 할당한다. 배운 개념을 마냥 외우기 보다 적용하면서 익힌다.\n\n3.기타\n매일 일과 시작 때 회고/계획 진행. 일과 후에는 하지 않는다.\n더욱 많은 저녁 시간을 할애할 필요가 있다. \n',
#   '',
#   ''],
#  ['', '180813\n\nMON', '-', '-', '-', '-'],
#  ['', '180814\n\nTUE', '-', '-', '-', '-'],
#  ['', '180815\n\nWED', '-', '-', '-', '-'],
#  ['',
#   '180816\n\nTHU',
#   '불필요한 단어 제거(조사, 어미, 접사 등) \n성능 확인 \n필요한 단어 추출 및 라벨링 준비',
#   '5H\n\n1.개인 프로젝트 4H\n문장, 단어, 형태소로 나누기\n샘플 감성 분석 시도\n\n2.스터디 \n데사스+ 러닝플랜',
#   '단계 별로 진행하니, 진행 속도가 빠르다.\n\n스터디, 프로젝트, 업무를 효율적 혹은 유기적으로 관리할 수 있는 방법은 무엇일까.\n\n개인 프로젝트 keep. 한 달 동안 업무에 적응하는 것이 우선이다.',
#   '프로젝트와 스터디를 따로 관리해야 하는지 고려해볼 것.'],
#  ['',
#   '180817\n\nFRI',
#   '',
#   '1프로젝트\nHarvardX강의 듣기 \n\n2클매 환경 셋팅 \n체크리스트 구비 \n기본 툴 사용 숙지 \n테크 블로그 정비\n수학, 파이썬(알고리즘) 숙지 \n',
#   '',
#   ''],
#  ['', '180818\n\nSAT', '', '테크 블로그 정리 \n', '', ''],
#  ['', '180819\n\nSUN', '-', '-', '-', '-'],
#  ['', '', '', '', '', ''],
#  ['32',
#   'TOTAL',
#   '강의노트 정리\n모형결합의 기초 1440-1511(31)\n부스팅 방법 1511-1602(51)\n퍼셉트론 1610-1640(30)\n서포트 벡터 머신 1640-1702(22)\n서포트 벡터 머신 0943-1038\n커널 서포트 벡터 머신 1045-1109\n신경망 기초 이론 1110-1127 *** 추후 복습 필요\nTheano 패키지 소개\n\n팀 프로젝트                                                                                               \n지난 프로젝트 회고 참고 O\n프로젝트 xgboost 모델링 O\n프로젝트 TODO 만들기 X\nkernel 참고 O(참고할 만한 커널이 많지 않다)\nDepartment 그룹핑\nTripType 별 태그 붙이기\n새로운 독립변수 구상(\n성별, 연령대, 아이, 인종, 학력, 수입, 소비 유형, 쇼핑 단위)\n모델링 시도(XG부스트, LGB boost)\n\n개인 프로젝트 \nHeart Signal. 언론사 사설 데이터를 통해 언론과 정치권력의 관계를 분류한다.\n\n\n\n\n',
#   'HOW : 실전을 위한 시행착오 시간 늘이기(강의노트 정리, 프로젝트 모두)\n\n1.(스터디) 개념을 실제로 활용하기 위해서, 강의노트를 직접 쓰고 코딩한다. \n\n2.(프로젝트) 프로젝트에 더 많은 시간을 할당한다. 배운 개념을 마냥 외우기 보다 적용하면서 익힌다.\n\n3.기타\n매일 일과 시작 때 회고/계획 진행. 일과 후에는 하지 않는다.\n더욱 많은 저녁 시간을 할애할 필요가 있다. \n',
#   '1.강의노트의 마지막 부분(모형 최적화, 비대칭 데이터 문제)는 내용 정리보다 프로젝트를 진행하는 과정에서 습득하는 게 더 낫다. \n\n2.강의노트 정리와 프로젝트, 두 과업 모두 인사이트를 얻고 개선할 수 있지만, 프로젝트는 더욱 빨리 처리할 필요가 있다.\n\n3.잘 할 수 있는 분야, 관심 있는 분야에서 주제를 찾으니, 동력이 생긴다.',
#   '기존 PLAN 고수'],
#  ['',
#   '180730\n\nMON',
#   '강의노트 정리\n모형결합의 기초 1440-1511(31)\n부스팅 방법 1511-1602(51)\n퍼셉트론 1610-1640(30)\n서포트 벡터 머신 1640-1702(22)\n\n팀 프로젝트 2H                                                                                               \n지난 프로젝트 회고 참고 O\n프로젝트 xgboost 모델링 O\n프로젝트 TODO 만들기 X\nkernel 참고 O(참고할 만한 커널이 많지 않다)\n\n개인 프로젝트 \n레퍼지토리 만들기 X\n주제 확정 X\n10m이라도 진행 X',
#   '3.5H\n\n1.강의노트 정리 1.5H\n모형결합의 기초\n부스팅 방법\n퍼셉트론\n서포트 벡터 머신\n커널 서포트 벡터 머신\n모형 최적화\n비대칭 데이터 문제\n\n2.팀 프로젝트 2H\n지난 프로젝트 회고 참고\n프로젝트 TODO 만들기\nkernel 참고\n\n## 스터디 \n',
#   '2H 14m +a\n\n1.강의노트의 마지막 부분(모형 최적화, 비대칭 데이터 문제)는 내용 정리보다 프로젝트를 진행하는 과정에서 습득하는 게 더 낫다. \n\n2.강의노트 정리와 프로젝트, 두 과업 모두 인사이트를 얻고 개선할 수 있지만, 프로젝트는 더욱 빨리 처리할 필요가 있다.',
#   '1. 개념 습득보다 개념 적용을 목적으로 한다.\n2. 강의노트와 프로젝트 기록 분리.'],
#  ['',
#   '180731\n\nTUE',
#   '서포트 벡터 머신 0943-1038\n커널 서포트 벡터 머신 1045-1109\n신경망 기초 이론 1110-1127 *** 추후 복습 필요\nTheano 패키지 소개\n\n팀 프로젝트\nDepartment 그룹핑\nTripType 별 태그 붙이기\n새로운 독립변수 구상(\n성별, 연령대, 아이, 인종, 학력, 수입, 소비 유형, 쇼핑 단위)\n모델링 시도(XG부스트, LGB boost)\n\n개인 프로젝트\n레퍼지토리 만들기\n주제 확정\n10m이라도 진행',
#   '4H\n\n1.강의노트 정리 2H\n서포트 벡터 머신\n커널 서포트 벡터 머신\n신경망 기초 이론\nTheano 패키지 소개\n\n2.개인 프로젝트\n레퍼지토리 만들기\n주제 확정\n10m이라도 진행\n\n3.팀 프로젝트\nDepartment 그룹핑\nTripType 별 태그 붙이기\n새로운 독립변수 구상(\n성별, 연령대, 아이, 인종, 학력, 수입, 소비 유형, 쇼핑 단위)\n모델링 시도(XG부스트, LGB boost)\n',
#   '-',
#   '-'],
#  ['', '180801\n\nWED', '-', '팀 프로젝트 발표 준비, 발표, 정리', '-', '-'],
#  ['',
#   '180802\n\nTHU',
#   '프로젝트 기획. \n\nHeart Signal. 언론사 사설 데이터를 통해 언론과 정치권력의 관계를 분류한다.\n',
#   '1.강의노트 정리\ntenflow 패키지 소개\nkeras 패키지를 활용한 신경망 구현\n그레디언트 소멸 문제 \n신경망 성능 개선 \n신경망 최적화 방법\n\n2.프로젝트 \n데이터 EDA\n개요, 타임라인 설정',
#   '잘 할 수 있는 분야, 관심 있는 분야에서 주제를 찾으니, 동력이 생긴다.',
#   '매일 꾸준히 진행 상황 기록'],
#  ['',
#   '180803\n\nFRI',
#   '아이맥 활성화.',
#   'AWS에 모델 업로드\n개인 프로젝트 크롤링. 텍스트 감정 분석 테스트.\n팀 프로젝트 EDA 최종(FinelineNumber), 모델링\n아이맥 활성화.',
#   '',
#   ''],
#  ['', '180804\n\nSAT', '', '전처리, 모델링, 정리(EDA), 사설 크롤링(중앙)', '', ''],
#  ['',
#   '180805\n\nSUN',
#   '모델링',
#   '전처리, 모델링, 정리(EDA), 사설 크롤링(중앙)\n나이브 베이즈 설명 추가\nEDA 정리 완료\nUpc 클러스터링 결과 반영 후 모델링',
#   '',
#   ''],
#  ['', '', '', '', '', ''],
#  ['31',
#   'TOTAL',
#   '강의노트 정리, 코드화\n엔트로피 1630-1700(30)\n엔트로피 1500-1540(40)\n의사 결정 나무 1540-1604 1620-1704 1711-1750(117)\nK-means 클러스터링 0945-1021 1053-1111\n1125-1200(89)\nAffinity Propagation 1200-1240(40)\n계층적 클러스터링 1240-1309(29)\n가우시안 혼합 모형과 EM 방법 1540-1608(28)\n모형 결합의 기초 1620-1636 1743-1820(53)\n\n프로젝트\n팀프로젝트 점검 1700-1730(30)\n개인 프로젝트 자료 서칭(DATASHOP, KAGGLE)\nDepartment 그룹핑, 모델링 시도(XG부스트) 2100-2400(180)\n\n기타\nsql 과제 1140-1415(155)\n몽고 DB 복습 1/2\n이력서 수정 1400-1600\n우아한형제들 권정민 데이터분석가 특강. 내용 정리.\n\n',
#   'HOW : 선순환 구조 유지\n\n1.선순환 구조 유지\n다른 수강생, 강사님(박사님)의 도움을 받아서 개념 숙지.\n팀(개인) 프로젝트에 응용.\n\n2.스터디, 프로젝트 두 축으로 진행\n(스터디 : 개념 숙지, 프로젝트 : 개념 응용)\n\n3.기타\n더욱 많은 저녁 시간을 할애할 필요가 있다. \n과제를 수행하면서 퀴즈에 대비하는 것이 효율적일 수 있다. ',
#   '1. 제대로 배우고 익히기 위해서는, 모든 예제를 직접 쓰고 코드화해봐야 한다. 그렇지 않고서는 손에, 머리에 익지 않는다.\n> 강의노트 정리에 더 많은 시간을 할애한다.\n> 분류, 클러스터링, 회귀분석 때 배운 모델링을 코드화하고 정리한다(스쿨 이후)\n\n2. 팀프로젝트에 시간 할당이 적다. 강의노트 정리의 본 목적은 프로젝트인 만큼, "적용"을 간과해서는 안 된다.\n> 프로젝트 수행에 더 많은 시간을 할당할 필요가 있다. \n\n3. 필드에서 제 역할을 하기 위해서는 기초 역량(확률론, python, sql)을 제대로 숙달해야 한다.(정민님)\n> 당장 나의 니즈와 직접적으로 연결되지 않는다고 해서 포기하기 보다 유보할 수 있도록 해야 한다. ',
#   '1.(스터디) 강의노트를 직접 쓰고 코딩한다. \n\n2.(프로젝트) 프로젝트에 더 많은 시간을 할당한다. 배운 개념을 마냥 외우기 보다 적용하면서 익힌다.\n\n3.매일 일과 시작 때 회고/계획 진행. 일과 후에는 하지 않는다.'],
#  ['',
#   '180723\n\nMON',
#   '1.이력서 수정 1400-1600\n\n2.강의노트 정리\n엔트로피 1630-1700\n의사 결정 나무 \n모형 결합의 기초 \n부스팅 방법\n\n3.팀프로젝트 점검 1700-1730',
#   '3H\n\n1.수업 복습, 퀴즈 준비 2H\n엔트로피\n의사 결정 나무 \n모형 결합의 기초 \n부스팅 방법 \n\n몽고DB\n\n2.팀 프로젝트 점검 30m \n자료, 코드 공유 \n\n3.이력서 수정(career) 30m\n\n',
#   '3H \n\n1.nosql 등, 아직 직접적으로 나의 니즈와 연결되지 않는 기술은 익힐 동기가 잘 생기지 않는다. \n\n2.집중적으로 시간을 투자해서 성과를 내지 못하는 상황이다.',
#   '1. 억지로 시간을 쪼개어 배우기보다는, 배우고 싶은 마음이 들 때 까지 유보한다. \n\n2. 의식적으로 집중할 수 있는 환경을 조성한다. (미디어)\n\n'],
#  ['',
#   '180724\n\nTUE',
#   'sql 과제 \n1140-1415(155)\n\n강의노트 정리\n엔트로피 1500-1540(40)\n의사 결정 나무 1540-1604 1620-1704 1711-1750(117)\n',
#   '4H\n\n- 지금 당장 필요한 것을 배우고 바로 적용\n분류, 클러스터링, 데이터 분석 위주 \n- 집중할 수 있는 환경을 조성하여 수련, 작업\n미디어\n\n1.강의노트 정리 2H\n의사 결정 나무 \n모형 결합의 기초 \n부스팅 방법 \n퍼셉트론\n서포트 벡터 머신\n커널 서포트 벡터 머신\n모형 최적화\n비대칭 데이터 문제\n\n2.sql 과제 1H\n\n3.팀 프로젝트\n인사이트 정리\n',
#   '5H 12m\n\n1. 모델을 제대로 익히고 활용하기 위해서는, 모든 예제를 코드화해봐야 한다. 그렇지 않고서는 손에, 머리에 익지 않는다.\n> 강의노트 정리에 더 많은 시간을 할애한다.\n> 분류, 클러스터링, 회귀분석 때 배운 모델링을 복습한다.(스쿨 이후)\n> 팀, 개인 프로젝트 대비 로지스틱 회귀분석, QDA/LDA, 나이브 베이즈정리 실습.\n\n2. sql 과제 수행에 생각보다 시간이 훨씬 더 많이 필요하다.(1H >> 2H 35m). \n> CS 과제가 있을 때는, 수업 후 곧바로 복습하며 과제를 시작한다.\n\n3. 팀프로젝트에 시간 할당이 적다. 사실 데이터 분석 강의노트 정리, CS 수련의 본 목적은 프로젝트이다. 프로젝트를 진행하기 위해서 배우고 익혔기 때문. \n> 개념, 코드를 응용해야.',
#   '1. 강의노트 정리 : 팀, 개인 프로젝트 대비 로지스틱 회귀분석, QDA/LDA, 나이브 베이즈정리 실습.\n2. 팀프로젝트 진행 시간 확보. '],
#  ['',
#   '180725\n\nWED',
#   '스터디 준비, 강의노트 정리(클러스터링) \nK-means 클러스터링 0945-1021 1053-1111\n1125-1200(89)\nAffinity Propagation 1200-1240(40)\n계층적 클러스터링 1240-1309(29)\n가우시안 혼합 모형과 EM 방법 1540-1608(28)\n모형 결합의 기초 1620-1636 1743-1820(53)',
#   '5H\n\n- 강의노트 예제, 연습문제 전부 코딩.\n- 팀프로젝트 진행 시간 확보. \n\n1.스터디 준비 / 강의노트 정리 2H\nMLE(가우시안 혼합 모형과 EM 방법, ...) ***\n조건부 기댓값(...), Affinity Propagation *\n\n모형 결합의 기초 \n부스팅 방법 \n퍼셉트론\n서포트 벡터 머신\n커널 서포트 벡터 머신\n모형 최적화\n비대칭 데이터 문제\n\n2.팀프로젝트 3H\n인사이트 리스트업\nTripType 별 태그 붙이기\n새로운 독립변수 구상(성별, 쇼핑 단위 - 혼자/가족, 소비 유형)\nVisitNumber 단위로 상세하게.',
#   '약 4H (239m)\n\n1.\n강의노트 정리, 스터리를 하면서 클러스터링과 가우시안 혼합 모형 간 관계를 명확하게 알 수 있었다.\n프로그래밍은 직접 생각하고, 시도한 만큼 실력이 느는 것 같다.\n\n2.팀 프로젝트 퍼포먼스가 생각보다 잘 나지 않는다. 할 일에 비해 할 시간이 부족하기 때문이다.',
#   '시간이 부족해도 회고는 꾸준히 해야 한다. 적은 시간을 가장 잘 활용하기 위해서다.'],
#  ['',
#   '180726\n\nTHU',
#   '-\n우아한형제들 권정민 데이터분석가 특강. 내용 정리.\n몽고 DB 복습 1/2\n',
#   '1.강의노트 개념 정리\n부스팅 방법\n퍼셉트론\n서포트 벡터 머신\n커널 서포트 벡터 머신\n모형 최적화\n비대칭 데이터 문제\n로지스틱 회귀분석, QDA/LDA\n\n몽고DB 복습 \n\n팀프로젝트 \nDD 취합(그룹핑)',
#   '-',
#   '-'],
#  ['',
#   '180727\n\nFRI',
#   '개인 프로젝트 \n자료 서칭(DATASHOP, KAGGLE)\n\n데이터 관련 글 읽기',
#   '6H\n\n팀 프로젝트\nDepartment 그룹핑\nTripType 별 태그 붙이기\n새로운 독립변수 구상(\n성별, 연령대, 아이, 인종, 학력, 수입, 소비 유형, 쇼핑 단위)\nVisitNumber 단위로 상세하게.\n\n퀴즈 오답노트, nosql 복습(sort~)\n테스트 오답노트 정리\n\n개인 프로젝트 \n문제 정의\n데이터 확보(정보공개청구, 커뮤니티)\n\n강의노트 실습\n부스팅 방법\n퍼셉트론\n서포트 벡터 머신\n커널 서포트 벡터 머신\n모형 최적화\n비대칭 데이터 문제',
#   '-',
#   '-'],
#  ['', '180728\n\nSAT', '-', '-', '-', '-'],
#  ['',
#   '180729\n\nSUN',
#   '강의노트 정리 \ntheano 복습\n\n팀 프로젝트\nDepartment 그룹핑, 모델링 시도(XG부스트)\n2100-2400',
#   '팀 프로젝트\nDepartment 그룹핑\nTripType 별 태그 붙이기\n새로운 독립변수 구상(\n성별, 연령대, 아이, 인종, 학력, 수입, 소비 유형, 쇼핑 단위)\n모델링 시도(XG부스트)\n',
#   '-',
#   '-'],
#  ['', '', '', '', '', ''],
#  ['30',
#   'TOTAL',
#   '강의노트 정리\n한국어 자연어처리 환경설정 1755-1830(35)\nMLE 모수 추정 1433-1453(20)\n분류 샘플데이터 소개, 분류용 가상데이터 생성 방법 1630-1705(35)\n전처리 기능 1716-1742(26) 1952-2048(56)\n분류의 기초 2050-2110(20)\n문서 전처리 0945-1010(25) 1105-1150(70)\n나이브 베이즈 분류 모형 1250-1353(63)\n분류의기초 1430-1500(30)\n다중 클래스 분류 \n분류 성능 평가 \n\nSQL 과제 \nSELECT 1410-1454(44)\nGROUPBY, HAVING 1503 - 1526(23)\n\n팀프로젝트(환경구축, EDA)\n환경구축 : 데이터셋 다운, 레퍼지토리, 디스크립션 1540-1718(98)\nEDA : 1630-1800(90)\nEDA : 0330-0500(90)\n\n회고, 기타\n오답노트 작성 07.13 ~ 07.20 1140-1222(102)\n모의면접 준비, 피드백/인사이트 정리 0900-1400\n개인프로젝트 구상중. 부실대학 예측 모델.',
#   'HOW : 선순환 행동 구조 구축\n\n(i) 공간/시간/사람 조정\n> 패스트캠퍼스에서 9:00-22:00 동안 다른 수강생과 함께.\n\n(ii) 박사님 강의노트를 온전히 이해, 적용. \n강의노트(+외부 교보재)를 나의 말로 적는다. 이해가 잘 되지 않는 부분은, 주변 사람들의 도움을 받아 이해할 수 있도록 노력한다.(매니저님, 박사님, 다른 수강생 분들)\n배운 개념을 적용한 프로그램(코드)를 작성한다.(팀 프로젝트 포함)\n수업 시작 전 예습한다.(10~30분)\n\nWHAT : 개념 다지기, 코드 작업량 늘리기\n\n(i) 개념 정리, 코드 구현\n(ii) ',
#   '0.수련 시간 801m(13H 21m)\n강의노트 정리 354m\nSQL 과제 67m\n팀 프로젝트 278m\n회고 102m\n\n1. 공간/시간/사람 조정 \n월-토 1800-2200 전부 개인시간 활용. 수련 가능시간 16~20H(11~14H) 만큼 줄어 들었다.\n> 더욱 많은 저녁 시간을 할애할 필요가 있다. \n\n2.수학, 데이터 분석 스터디 재시작(with 효열님)\n강의노트 개념을 정리하고 설명할 기회가 생겼다. 예전처럼 스터디, 프로젝트 두 축으로 진행할 수 있게 되었다.(스터디 : 개념 숙지, 프로젝트 : 개념 응용)\n\n3.SQL 복습을 수행하는데 시간을 쏟지 못했다.\n> 과제를 수행하면서 퀴즈에 대비하느 것이 효율적일 수 있다. \n\n4.',
#   '1.스터디, 프로젝트 두 축으로 진행\n(스터디 : 개념 숙지, 프로젝트 : 개념 응용)\n\n2.선순환 구조 유지\n다른 수강생, 강사님(박사님)의 도움을 받아서 개념 숙지.\n팀(개인) 프로젝트에 응용.\n\n3.기타\n더욱 많은 저녁 시간을 할애할 필요가 있다. \n과제를 수행하면서 퀴즈에 대비하는 것이 효율적일 수 있다. '],
#  ['',
#   '180716\n\nMON',
#   '모의면접 준비, 피드백/인사이트 정리 0900-1400\n\n수업 준비(환경설정) 1755-1830\n\n강의노트 정리\nMLE 모수 추정 1433-1453\n분류 샘플데이터 소개, 분류용 가상데이터 생성 방법 1630-1705\n전처리 기능 1716-1742 1952-2048\n분류의 기초 2050-2110',
#   '4H\n\n1.모의 면접 준비\n\n2. 강의노트(화, 토) 개념 정리, 코드 구현 \nMLE 모수 추정\n분류의 기초(샘플 데이터 생성, 전처리, 다중 클래스, 분류 성능 평가)\n로지스틱 회귀분석\nQDA, LDA\n\n3. 수업 준비(환경 설정)',
#   '1. 실질적으로 많은 시간을 투자하니, 성과가 생긴다. \n수업 준비(환경 설정) 35m\n강의 노트 정리(~분류의 기초) 160m\n\n2. 외우면서 시도하기. \n개념, 코드를 보면서 작성하지 않고 외우면서 하면, 더욱 기억에 오래 남는다. ',
#   '1. 매일 강의 예습, 복습 시도.(시간 투자 증대)\n2. 개념, 코드를 외우면서 작성.'],
#  ['', '180717\n\nTUE', '', '예비군', '', ''],
#  ['', '', '', '', '', ''],
#  ['',
#   '180718\n\nWED',
#   '강의노트\n문서 전처리 0945-1010 1105-1150(70)\n나이브 베이즈 분류 모형 1250-1353(63)\n나이브 베이즈 감성 분석\n다중 클래스 분류 \n분류 성능 평가 \n로지스틱 회귀분석 \nQDA, LDA\n\nsql 과제 \nSELECT 1410-1454(44)\nGROUPBY, HAVING 1503 - 1526(23)\n\n팀프로젝트 환경구축\n데이터셋 다운, 레퍼지토리, 디스크립션 1540-1718(98)\n\n\n\n',
#   '6H\n\n1. 강의노트(화, 토, 월) 개념 정리, 코드 구현 3H\n나이브 베이즈 분류 모형 \n나이브 베이즈 감성 분석\n다중 클래스 분류 \n분류 성능 평가 \n-\n로지스틱 회귀분석 \nQDA, LDA\n\n2. 팀프로젝트 환경구축, EDA 2H\n데이터셋 다운로드\n레퍼지토리 만들기\ndescription으로 전체 그림 파악하기 \n\n종속변수의 특성 파악 \n개별 독립변수 특성 파악 \n결측치\n\n3.sql 과제 1H\n\n4. 개인프로젝트 준비 \n3개 데이터셋으로 추리기 \n',
#   '5H\n\n1.배운 내용(강의노트)의 개념, 코드를 다시 적용하는 시간이 부족했다. \n2.강의노트 개념, 코드를 다시 따라하기만 하다보니 금새 지루해졌다.\n3.sql 과제 달성에 생각보다 많은 시간 소요. 수업 후 복습을 하지 않았기 때문.\n',
#   '1. 목, 금을 활용하여 밀린 강의노트를 전부 다 정리한다. \n2. 강의노트 내용을 팀프로젝트에 적용한다.(질리지 않고 계속할 수 있도록)\n3. 개인 프로젝트 준비 필요.'],
#  ['',
#   '180719\n\nTHU',
#   '강의노트\n분류의기초 1430-1500\n다중 클래스 분류 \n분류 성능 평가 \n\n팀 프로젝트 EDA 1630-1800\n\n기수강생 특강(지속가능발전소 서원영)',
#   '3H\n\n1.강의노트 정리 2H\n나이브 베이즈 감성 분석\n다중 클래스 분류 \n분류 성능 평가 \n로지스틱 회귀분석 \nQDA, LDA\n\n2.팀 프로젝트 EDA\n\n3.개인 프로젝트 준비',
#   '2H\n\n1.강의노트 내용을 기계적으로 답습하려고 하다보니, 많이 지루했다. \n> 그 내용을 어떻게 응용하면 좋을지, 상상하고 실제로 구현한다.(팀, 개인프로젝트, 포스트스쿨)\n\n2.팀프로젝트에 생각보다 기여도가 높지 않다. 저번 팀 프로젝트와 유사한 패턴. \n> 지난 프로젝트 회고를 참고하여, 새로운 전략을 실천한다.',
#   '1. 결국 데이터사이언스는 도구. 작은 것부터 하나씩 적용해본다. \n(팀, 개인프로젝트, 포스트스쿨)\n\n2.회고록 다시 살펴보기. 프로젝트 진행에 적용하기'],
#  ['',
#   '180720\n\nFRI',
#   '오답노트 작성 1140-1222\n07.13 ~ 07.20\n\n강의노트 정리. 스터디 결성(효열님)\n휴식.',
#   '6H\n\n1.오답노트 작성(sql 과제)\n07.13 ~ 07.20 1H\nsql 과제 1/2 30m\n\n2. 강의노트 정리(코드 구현) 2H\n로지스틱 회귀분석 \nQDA, LDA\n나이브 베이즈 감성 분석\n\n3.팀 프로젝트 진행 2H 30m\nHOW : \n1지난 회고록 참고\n2자동화할 수 있는 것은 곧바로 적용(함수)\n3큰 것부터 작은 것으로\n4진행상황, 인사이트 계속 기록\n\nTripType 21~30 전부 시각화 \nDepartment 가설 세우기\n\n\n',
#   '-',
#   '-'],
#  ['',
#   '180721\n\nSAT',
#   '팀 프로젝트 2H\n휴식.',
#   '팀 프로젝트 2H\nHOW : \n1지난 회고록 참고\n2자동화할 수 있는 것은 곧바로 적용(함수)\n3큰 것부터 작은 것으로\n4진행상황, 인사이트 계속 기록\n\nTripType 21~30 전부 시각화 \nDepartment 가설 세우기\n\n\n',
#   '-',
#   '-'],
#  ['', '180722\n\nSUN', '휴식.', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['29', '180710\n\nMON', '프로젝트 회고. \n블로그 글쓰기.', '-', '-', '-'],
#  ['',
#   '180711\n\nTUE',
#   '1.프로젝트 회고(EDA) 5H\n2.분류의 기초 수업',
#   '1. 프로젝트 회고(데이터 분석 개념 정리, 코드 구현)\n\n2.퀴즈 준비. 오답 노트 정리.\n테스트, 퀴즈 정답 적기(따로 오답노트는 만들지 않는다)\n',
#   'LIKE\n1.직접 구현하며 정리하다보니 제대로 배우는 것 같다.\n\nWISH\n1.프로젝트 회고에 생각보다 많은 시간이 필요하다. \n2.분류 개념이 다소 많고 추상적.\n',
#   '1.프로젝트 회고에 더 많은 시간 투자. 다음 프로젝트를 시작하기 전, 제 때 마무리 지을 수 있도록.\n\n2.강의 노트(분류의 기초, 클러스터링) 내용 정리, 코드 시도.(쉬운 코드부터) 두 번째 팀 프로젝트, 개인 프로젝트 때 응용할 수 있도록. \n\n3.오답노트 정리 \n배운 내용 정리하는 식으로.'],
#  ['',
#   '180712\n\nWED',
#   '프로젝트 퇴고 1038-1720',
#   '5H\n\n1.프로젝트 퇴고. 3H\nfeature selection, ols, 변수변환, 다항회귀, 아웃라이어 제거, VP, \n\n2.강의 노트(분류의 기초, 클러스터링) 내용 정리, 코드 구현. 2H\n커밋에 올리도록 한다. \n\n3.오답노트 정리 30m\n배운 내용 정리하는 식으로 간단하게.',
#   'LIKE\n프로젝트 전 과정을 직접 시도하니, 모호한 개념도 정리할 수 있는 것 같다.\n\nWISH\n강의 노트, 내용 정리 등에 더 많은 시간이 필요하다',
#   '-'],
#  ['',
#   '180713\n\nTHU',
#   '프로젝트 퇴고 마무리 (캐글 업로드)\n오답노트 정리 1730-1800, 1845-1725\n0615~0712 정리 \n팀 프로젝트 주제 선정, 구상(+개인) _ 월마트',
#   '1.프로젝트 퇴고 마무리 (캐글 업로드) \n2.오답 노트 정리\n3.강의 노트(분류의 기초, 클러스터링) 내용 정리\n4.팀 프로젝트 주제 선정, 구상. \n5.개인 프로젝트 구상. ',
#   'LIKE \n1오답노트 정리. 매일 조금씩 정리할 수 있도록. 단, 강의 노트 정리를 우선순위로. \n2회고(오답노트, 프랙티스 로그)\n\nWISH\n내가 데사스를 들으려고 했던 이유는 무엇일까. 데이터사이언스도 결국 도구라는 것을 잊지 않아야.',
#   '1.박사님 수업 복습.\n2.모든 데이터 다운로드 후 살펴보기.'],
#  ['',
#   '180714\n\nFRI',
#   'X : 성당 행사',
#   '박사님 수업 내용 정리(클러스터링, 분류, ~)\n프로그래밍 수련 \n\n',
#   '-',
#   '-'],
#  ['',
#   '180715\n\nSAT',
#   'X : 성당 행사',
#   '',
#   '0. 현재 상황 진단\n감정 : 불안함. 내가 가진 자원으로 해결하기 어려운 문제를 마주했기 때문이다. 실력보다 난이도가 높은 상태.\n상황 : \n(i) 개념을 온전히 소화하지 못했다\n(ii) 코딩이 익숙하지 않다\n\n1. 원인 파악\n(i) 배움보다, 다른 것에 더 관심이 있다.(peaceful warrior의 다른 선수들) \n(ii) 현재 배우는 내용과, 앞으로 내가 하고 싶은 일이 유기적으로 연결되지 않는다\n(iii) 스스로 적극적으로 배우려고 하지 않고, 통계학/머신러닝에 상대적으로 적은 시간 투자.',
#   '해결책 구상\n\n(i) 목적, 동기 다시 부여\n(ii) 행동 구조(선순환. 공부 X 휴식) 구축 - (DD 플랜)\n(iii) 선택과 집중, 그리고 직면한다 (DD 액션)\n(iv) 작은 성공을 해본다 (배운 내용 기반 개인 프로젝트)\n(v) 주변 사람에게 따뜻한 지지, 객관적 / 구체적 피드백을 받는다 (감정 받아들이기)\n\n개념 : 강의노트 예습, 복습\n코드 : 강의노트 수련(매일 일정 시간)'],
#  ['', '180716\n\nSUN', 'X : 성당 행사', '-', '-', '-'],
#  ['', '', '', '', '', ''],
#  ['27',
#   'TOTAL',
#   '',
#   '선택적, 유기적 배움 시도. 24H (9:00-22:00)\n\n(i) 프로젝트 : 수업 내용 끊임없이 반복해서 "적용"(PBL)\n> 박사님 수업 내용 응용(데이터 분석 위주) \n> 강사님 수업 내용 응용(파이썬 패키지 위주)\n\n(ii) 스터디 : 강의노트 "개념 이해/정리" + 베이지안 추정 공부. \n\n(iii) 회고 : 엇나가지 않도록 "되돌아보기"\npractice log(1), 오답노트 // 단, 퀴즈 테스트 준비는 따로 하지 않는다.(2)\n\n\n',
#   '',
#   ''],
#  ['', '180625\n\nMON', '-', '-', '-', '-'],
#  ['',
#   '180626\n\nTUE',
#   '베이지안 교재 1장 읽기, 코드 구현하기 \n1005-1133\n1141-1335. \n\n도커 설치. 잠정 중단.\n\n강의노트 리뷰. 개념 이해, 정리\n1522-',
#   '6H\n\n1.베이지안 교재 1장 읽기, 코드 구현하기 3H\n- 내용 이해 \n- 코드 구현\n\n2.강의노트 리뷰. 개념 이해, 정리. 1H\n- 핵심 이슈, 질문 선별하기. \n- 설명 작성하기. \n\n3.프로젝트. 강의 개념 적용하기. 2H\n- 속성 별 분포 검정 / 모수 검정 \n- \n\n4.오답노트 작성하기 1H\n수학 테스트1, 플밍(가장 최근) 1',
#   '',
#   ''],
#  ['', '180627\n\nWED', '', '-', '', ''],
#  ['', '180628\n\nTHU', '', '-', '', ''],
#  ['', '180629\n\nFRI', '', '-', '', ''],
#  ['', '180630\n\nSAT', '', '-', '', ''],
#  ['', '180701\n\nSUN', '', '-', '', ''],
#  ['', '', '', '', '', ''],
#  ['26',
#   'TOTAL',
#   'Math\n강의노트 "상관 관계" : 개념 정리, 코드 리뷰 1830-1950(80m), 2003-2053(50m)\n수학 스터디, 향후 계획 논의 (1000-1600)\n\nCS\n프로젝트 구글 스프레드시트 공유\n프로젝트 EDA 엑셀 파일 정리(11:00-11:40)\n\nrequest / selenium / scrapy 복습 1412-\nrequest 복습(코드 시도)\nrequest / selenium / scrapy 복습\n\nETC\n이력서 작성(3H)',
#   'HOW : 내실 다지기 + 외부로 확장하기\n(i) 회고(복습, 오답노트, TIL)\n(ii) 베이지안 스터디 : 수학(강의 노트), 베이지안\n(iii) 프로젝트 : 프로그래밍, 데이터 분석 기법 적용, 데이터 스토리텔링(근거 기반)\n\nWHAT : \n\nMath : 베이지안 스터디\n(i) 박사님 강의노트 : 개념 정리, 코드 리뷰\n(ii) 스터디 준비 : 핵심 이슈 정리, 교재 읽기 / 진행\n(iii) 오답노트 만들기\n\nCS : 프로젝트 \n(i) 강사님 수업 개념 정리, 코드 리뷰 : 매일 2H\n(ii) 프로젝트 준비 : 핵심 개념 적용하기 / 진행\n(iii) 오답노트 만들기\n\nETC\n데일리 커밋, TIL 작성',
#   '\nRETRO\n1제대로 회고를 하지 못한다. 충분히 시간을 들여 회고를 하기에는, 공부량이 매우 많다. \n2퀴즈, 테스트 오답 노트를 만들지 않았다. 어떤 개념을 내가 아는지 알지 못하는지 명확하게 파악하지 못하는 상황이다. \n> 오답노트, 데일리커밋, TIL, 프랙티스 로그 중 지금 가장 중요한 것만 할 수 있도록 시간을 안배한다. \n\n프로젝트\n1퀴즈, 테스트 공부와 실제 프로젝트 수행 능력 간 상관관계가 높지 않다. 다시 말해 퀴즈, 테스트 성적이 좋다고 해서 데이터 분석 및 관련 프로그래밍을 잘하는 것이 아니다. \n> 수업, 스터디, 프로젝트가 유기적으로 작동하도록 하기 위한, 통합적 배움을 위한 액션 아이템을 선정한다. \n\n박사님 강의노트\n1박사님 강의를 들을 때, 해당 개념이 어떤 위치에서 어떤 역할을 수행하는지 명확하게 인지하지 못한다. 배운 개념과 응용 사례 간 "전이"가 잘 되지 않는 상황. \n2강사님 수업 내용보다 박사님 수업 내용에 훨씬 더 많은 시간을 할애하여 이해하는 것이 중요하다. 단순히, 수학(및 데이터 분석) 혹은 프로그래밍으로 나눌 것이 아니다. ',
#   'HOW : 선택적, 유기적 배움 시도\n(i) 프로젝트 : 수업 내용 끊임없이 반복해서 "적용"(PBL)\n> 박사님 수업 내용 응용(데이터 분석 위주) \n> 강사님 수업 내용 응요(파이썬 패키지 위주)\n\n(ii) 스터디 : 강의노트 "개념 이해/정리" + 베이지안 추정 공부. \n\n(iii) 회고 : practice log(1), 오답노트 // 단, 퀴즈 테스트 준비는 따로 하지 않는다.(2)\n'],
#  ['', '180618\n\nMON', '-', '-', '-', '-'],
#  ['', '180619\n\nTUE', '-', '-', '-', '-'],
#  ['',
#   '180620\n\nWED',
#   'Math\n수학 스터디, 향후 계획 논의 (1000-1600)\n강의노트 "상관 관계" : 개념 정리, 코드 리뷰 1830-1950(80m), 2003-2053(50m)\n\nCS\n프로젝트 준비 X\n\nRE\nTIL 작성 X\n이력서 작성 X',
#   '4H\n\n1. 박사님 강의노트 "상관 관계", "검정 추정" : 개념 정리, 코드 리뷰\n2. 프로젝트 : 데이터 디스크립션 참고, NaN 처리 서칭\n3. 커리어서비스 : 자소서 개요 작성\n',
#   'Math ★★★★★\n1. 수학 스터디 방향 재수립. 강의노트, 베이지안 추정(교재) 중심으로. 앞으로 커리어 구축에 큰 도움이 될 것이라 생각한다. \n2 수업 복습과 스터디가 유기적으로 연결되는 것 같다. \n\nCS ★\n1. 시간 할애 X\n2. 프로젝트를 생각보다 열심히 하지 않는다.(필드였다면?)\n\nRE\n1. TIL을 왜 하는지, 어떻게 하는지 제대로 알지 못한다.',
#   '1. 프로젝트에 더 많은 시간을 할당한다.(프로젝트를 1순위로)\n2. 스터디를 준비할 겸, 강의노트 개념 정리, 코드 리뷰를 수행한다. \n3. 내가 왜 TIL을 작성하려고 했는지 자문한다. TIL과 프랙티스 로그, 데일리 커밋 간 차이는 무엇일까?'],
#  ['',
#   '180621\n\nTHU',
#   'request 복습(코드 시도)\n이력서 작성(3H)\n프로젝트 구글 스프레드시트 공유',
#   '5H \n\n1. 프로젝트 EDA : 디스크립션 읽기, NaN 처리 서칭. \n2. request 복습(코드 시도)\n3. 이력서 작성\n4. 박사님 강의노트 "검정 추정" 정리 \n',
#   '-',
#   '-'],
#  ['',
#   '180622\n\nFRI',
#   'request / selenium / scrapy 복습 1412-\n프로젝트 EDA 수행',
#   '1. 프로젝트 EDA\n2. request / selenium / scrapy 복습 \n',
#   '-',
#   '-'],
#  ['',
#   '180623\n\nSAT',
#   '프로젝트 EDA 엑셀 파일 정리(11:00-11:40)\nrequest / selenium / scrapy 복습\n',
#   '"검정과 추정" 복습\n"회귀 분석" 복습\nrequest / selenium / scrapy 복습\n프로젝트 EDA 엑셀 파일 정리(11:00-11:40)',
#   '-',
#   '-'],
#  ['', '180624\n\nSUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['25',
#   'TOTAL',
#   'Math\n\n최적화 개념 정리, 코드 구현 1400-1540(1H 40m)\n분포 개념 정리, 코드 구현1 1616-1657(41m)\n확률론 테스트 준비 1H\n연속 확률 분포 개념 정리, 코드 구현 1625-1645(40m)\n연속 확률 분포 개념 정리, 코드 구현 1655-1800(65m)\n\nKOCW 선형대수 18강 듣기(1H)\n\n수학 스터디 준비자료(고유분해의 성질, 코드로 증명) (3H)\n수학 스터디 응용사례, 샘플코드 (2H)\n수학 스터디 준비(pdf 파일 뜯어보기) 개념 참고하기 \n\n\nCS\nJS - 수업 복습 1800-1830\nsendmail - 수업 복습 1800-1830\n\n\nRE\n팀프로젝트 준비(데이터 뜯어보기, 헬로데이터과학 읽기) 1526-1615(49m)\n오답노트 작성 0611 math 2개\n오답노트 작성 0614\n',
#   '*HOW: 기초 역량을 꾸준히 쌓는다. 동시에 프로그래밍 현실화 역량은 더욱 중점적으로 쌓는다.\n\n1.매일 math, CS 기본기 수련하기. 확률과 통계, 알고리즘, 자료구조에 적은 시간이라도 투자한다. \n\n2.CS 파이썬 기본 개념 정리한다((문법, 패키지 중심으로. 나중에는 데이터사이언스 핸드북 등을 활용해서 확장한다)\n\n3.그 날 회고(practice note, 오답노트, TIL, 깃헙)은 바로 작성한다. 어떤 개념을 어떻게 이해하지 못했는지 점검한다. \n\n\n*WHAT 20H \n\n0.수업 따라하기 (예습, 복습) (하루 2H)\n1.개념 정리, 코드 구현 4H\n2.스터디 준비, 과제 4H\n\nI.기본기 다지기. (하루 2H ~ 3H)\nmath: 매일 KOCW 확률과통계 수강하기(1강보다 적어도 된다) \ncs: 매일 알고리즘 문제 풀고, 자료구조 수강하기(1강만 들어도 된다)\n\nII. 파이썬 기본 개념 정리 (하루 1H)\n매일 조금씩 파이썬 기본 개념을 노트에 정리한다. \n점프투파이썬, PY4E 두 가지 교재와 병행하면서 정리한다. 예를 들어, if 문에 대해서 정리할 때는 강사님 설명 +점프투 파이썬, PY4E의 내용까지 참고하는 식으로.\n\nIII.바로 회고 (하루30m)\n매일 practive note, 오답노트, TIL, 깃헙 작성하기. ',
#   '1.수학 스터디를 준비하면서, 기본 내용보다 더 깊숙하고 넓게 배울 수 있었다. \n\n2.수업 복습, 커리어서비스(기수강생 강의), 프로젝트 하는데도 많은 시간이 소요됐다. 보조 교보재를 참고할 여력이 없다. \n- KOCW 확률과통계 강의를 1,2강 외 수강하지 못했다. \n- 알고리즘, 자료구조 공부를 거의 하지 못했다. 하루 10분도 투자하지 못한 날이 많았다.\n- 파이썬 기본 문법, 패키지에 대해서 여러 교보재를 참고하면서 제대로 배우지 못햇다. \n\n3.배운 내용을 충분히 회고하지 못했다. \n- 프랙티스 로그, 데일리 커밋\n- 플밍, 수학 수업 \n- 오답노트\n',
#   '1.남은 9주 동안 무엇을 해야 할까? \n베이지안 스터디 교재 외 외부 교보재로 공부하지 않기. 대신 회고(복습, 오답노트 작성, TIL)를 통해 내실을 다진다.\n(i) 베이지안 스터디 : 수학(강의 노트), 베이지안\n(ii) 프로젝트 : 프로그래밍, 데이터 분석 기법 적용, 데이터 스토리텔링(근거 기반)\n(iii) 회고(복습, 오답노트, TIL)\n\n2.개인 공부(수업, 퀴즈, 테스트)와 프로젝트, 스터디를 유기적으로 할 수 있는 방법은 무엇일까?\n(i) 베이지안 스터디 때 강의노트를 충분히 습득한다. \n(ii) 프로젝트를 진행하며, 파이썬 문법 / 패키지 개념을 다시 참고/상기한다.\n(iii) 회고, 회고, 회고...!\n\n3.프로젝트, 스터디 모두 흥미 있게 할 수 있는 방법은 무엇일까?\n(i) 커리어서비스, 블로그 운영을 통해 프로젝트, 스터디가 내가 하고 싶은 바와 어떻게 연결되어 있는지 끊임없이 살핀다.'],
#  ['',
#   '180611\n\nMON',
#   '수학 스터디 준비자료(고유분해의 성질, 코드로 증명) (3H)\n수학 스터디 응용사례, 샘플코드 (2H)\nKOCW 선형대수 18강 듣기(1H)',
#   '6H\n\nMath \nKOCW 확률과통계 3강 1/2 듣기(1H)\n수학 스터디 준비(rest)\nCS\n알고리즘 문제 풀기(15m)\n자료구조 강의 3강 듣기(15m)\n',
#   'Math ★★★★★\n수학 스터디를 준비하면서, 기본 내용보다 더 깊숙하고 넓게 배울 수 있었다. \n스터디를 준비하다보니, KOCW 기본 개념(예, diagonalization)을 제대로 숙지해야 겠다고 생각했다. \n\nCS ★\n내일부터는 알고리즘, 자료구조 공부를 조금씩이라도 할 수 있도록. ',
#   ''],
#  ['',
#   '180612\n\nTUE',
#   '최적화 개념 정리, 코드 구현 1400-1540\n\n분포 개념 정리, 코드 구현1 1616-1657',
#   'Math\n최적화 개념 정리, 코드 구현\n분포 개념 정리, 코드 구현 \nKOCW 확률과통계 3강 듣기\n\nCS\n알고리즘 문제 풀기(15m)\n자료구조 강의 3, 4강 듣기(15m)\n\nRE\n오답노트 작성 0611 math 2개',
#   '',
#   ''],
#  ['',
#   '180613\n\nWED',
#   '오답노트 작성 0611 math 2개',
#   'Math \n분포 개념 정리, 코드 구현 \nKOCW 확률과통계 3강 듣기 \n\nCS\n알고리즘 문제 풀기(15m)\n자료구조 강의 3, 4강 듣기(15m)\n\nRE\n오답노트 작성 0611 math 2개',
#   '',
#   ''],
#  ['',
#   '180614\n\nTHU',
#   '팀프로젝트 준비(데이터 뜯어보기, 헬로데이터과학 읽기) 1526-1615\n연속 확률 분포 개념 정리, 코드 구현 1625-1645\n연속 확률 분포 개념 정리, 코드 구현 1655-1800\nJS - 수업 복습 1800-1830\n확률론 테스트 준비 1H\n\nsendmail - 수업 복습 1800-1830',
#   'Math \n분포 개념 정리, 코드 구현 \nKOCW 확률과통계 3강 듣기 \n오답노트 작성 0614\n\nCS\nJS, sendmail - 수업 복습\n\nRE\n오답노트 작성 0614',
#   'Math 3H 15m ★★★★\n스터디, 프로젝트, 커리어 서비스가 본격적으로 시작되면서 개인 공부 시간이 갈수록 줄어든다. \n> 스터디, 프로젝트 팀 안에서 수학, 플밍 공부를 보충하며 할 수 있도록. \n\nCS 30m ★★★',
#   ''],
#  ['',
#   '180615\n\nFRI',
#   '오답노트 작성 0614\n수학 스터디 준비(pdf 파일 뜯어보기) 개념 참고하기',
#   'Math \n수학 스터디 준비(pdf 파일 뜯어보기) 개념 참고하기\n\nCS \n프로젝트 데이터 셋 살펴보기',
#   '',
#   ''],
#  ['',
#   '180616\n\nSAT',
#   '',
#   'Math\n상관관계 복습\n\nCS\nEDA 10개 속성 뜯어보기(--)\nSMTP, request 복습(2H)',
#   '',
#   ''],
#  ['', 'SUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['24',
#   'TOTAL',
#   '\n*WHAT\n\nMath 11H 9m\n1.수업 내용 정리 3H 24m\n확률론. 노트에 개념 정리(1), 손코딩(2), 직접 코딩(3) (1.5H)\n확률론 노트 정리1540-1615(35m)\n베이즈 정리, 확률모형 노트 정리(45m)\n확률변수의 특징값, scipy 복습 1417-1453(34m)\n\n2.KOCW 확률과통계 4H 3m\nKOCW 선형대수 18강 듣기(1H)\nKOCW 확통 1강 1/2 2040-2120(40m)\nKOCW 확통 1강 1/2 듣기 1130-1219(49m)\nKOCW 확통 2강 듣기 14:10-15:44(1H 34m)\n\n3.스터디 5H 30m(스터디하는 시간 제외)\n수학 스터디 준비자료(고유분해의 성질, 코드로 증명) (3H)\n수학 스터디 응용사례, 샘플코드 (2H)\n수학 스터디.(5H)\n수학 스터디 코드 정리, 커밋(30m)\n\nCS 3H 05m\n알고리즘 문제 풀기(1H) \ndatastructure0, 1, 2 듣기(30m) 1625-1725(1H)\n알고리즘 1225-1300(35m)\n\nRE\nTIL 0 \nGIT 3',
#   '*HOW : DSS 과정을 온전히 이해하고 체화한다.\n- 개념 정리 : 수학, CS의 핵심 개념을 나의 언어로 다시 쓰며 숙지한다(실질적으로 중요한, 많이 쓰이는 개념 중심으로)\n- 보완 / 확장 : 외부 교보재로 해당 개념 보완, 확장한다.(수업 내용 중심으로)\n\n- 직접 시도 : 배운 수식, 코드는 연습장, jupyter notebook에 직접 구현한다. (+git commit!)\n- 인출 : 노트 정리, 외부 교보재로 보완/확장, 직접 시도로 기본 개념을 숙지한 다음, 스터디를 하면서 인출, 응용한다. \n- 회고 : 퀴즈, 테스트 틀린 문제, 온전히 알지 않고 맞춘 문제 개념은 다시 정리한다. \n\n* WHAT 24H\n\n파이썬 데이터사이언스 패키지 북 구입 \npy4e 교재 제본\n\nMath\n- 확률과통계 \n(i) 수업 내용 정리 : 예습, 복습(3H)\n(ii) KOCW 확률과통계 6강.조건부 평균까지. Math 노트, 수업 내용 뒷부분에 계속 갱신하면서 정리.(1.5H / 9H)\n(iii) 스터디 : 개념 숙지, 응용. 가능하면 매주 수요일 활용해서 과제할 것. 차후 복습(6H)\n\nCS\n- 자료구조, 알고리즘\n(i) 프로그래머스 알고리즘 풀기(30m / 3H)\n(ii) mycodeschool _ datastructure 듣기, 내용 정리(30m / 3H)\n\nJournal\n- 오답노트 작성\n- TIL은 하루에 한 줄 적듯 가볍게. \n- GIT은 지금처럼 숙제하듯 틈틈히.',
#   '개인 공부에 투자하는 시간이 갈수록 줄어든다. 가용시간을 고려한 계획이었는데도 그러하다. \n\n1.Math, CS를 꾸준히 개념정리할 시간을 따로 할당하지 않았다. 수업/스터디, 외부 교보재 수업, 자료구조, 알고리즘 공부를 하다보면 따로 노트에 개념을 적으며 습득할 시간이 없다. \n\n2."직접 시도"는 복습, 스터디, 알고리즘 문제 풀기를 하면서 충족. 단, 알고리즘/자료구조에 대한 이해, 그것을 코딩하는 역량을 높이기 위해서는 더욱 구체적으로 회고하며 개선해야 한다. \n\n3.KOCW 진도를 충분히 나가지 못한다. 매일 일정(수업, 퀴즈, 테스트, 스터디 등)에 따라 외부 교보재를 공부할 수 있는 시간이 다르다. \n\n4.프로그래밍 역량을 키우고 싶지만, 어떻게 해야 할지 감이 잘 오지 않는다. 알고리즘 문제를 풀고, 자료구조를 공부하고, 생활코딩 edwith에서 웹 언어와 생태계도 공부하지만 실력이 일취월장한다는 느낌은 받지 못하는 상황이다.\n\n5.알고리즘 문제를 푸는데 시간이 오래 걸린다. 그리고 효과적 해법을 도출하지 못한다.',
#   '기초 역량을 꾸준히 쌓는다. 동시에 프로그래밍 현실화 역량은 더욱 중점적으로 쌓는다.\n\n1.매일 math, CS 기본기 수련하기. 확률과 통계, 알고리즘, 자료구조에 적은 시간이라도 투자한다. \n\n2.CS 파이썬 기본 개념 정리한다((문법, 패키지 중심으로. 나중에는 데이터사이언스 핸드북 등을 활용해서 확장한다)\n\n3.그 날 회고(practice note, 오답노트, TIL, 깃헙)은 바로 작성한다. 어떤 개념을 어떻게 이해하지 못했는지 점검한다. '],
#  ['',
#   'MON',
#   '수학 스터디 준비자료(고유분해의 성질, 코드로 증명) (3H)\n수학 스터디 응용사례, 샘플코드 (2H)\nKOCW 선형대수 18강 듣기(1H)',
#   'Total 6H\n\nMath \n확률론 내용 정리(30m)\nKOCW 선형대수 18강 듣기(30m)\n\nCS\ncss-selector 내용 정리(1H)\n\n수학 스터디 준비자료 서칭',
#   'Math ★★★★★\n수학 스터디를 준비하면서, 기본 내용보다 더 깊숙하고 넓게 배울 수 있었다. \n스터디를 준비하다보니, KOCW 기본 개념(예, diagonalization)을 제대로 숙지해야 겠다고 생각했다. \n\nCS ★\n내일부터는 알고리즘, 자료구조 공부를 조금씩이라도 할 수 있도록. ',
#   '1.지난 주 배운 내용(확률론, HTML, CSS) 노트에 개념 정리(1), 손코딩(2), 직접 코딩(3)\n2.매일 조금씩 수학(KOCW, 교재), CS(자료구조, 알고리즘)에 투자'],
#  ['',
#   '180605\n\nTUE',
#   '\nMath\n확률론. 노트에 개념 정리(1), 손코딩(2), 직접 코딩(3) 1.5H\n수학 스터디.(5H)\n\nCS\n...',
#   'Total 2H\n\n1.지난 주 배운 내용(확률론, HTML, CSS) 노트에 개념 정리(1), 손코딩(2), 직접 코딩(3) 1.5H\n2.알고리즘 1문제, data structure 1강(30m)\n',
#   'Math ★★★★★\nCS ★\n',
#   ''],
#  ['', '180606\n\nWED', '', '휴무', '', ''],
#  ['',
#   '180607\n\nTHU',
#   '\nMath\n수학 스터디 코드 정리, 커밋(30m)\n확률론 노트 정리1540-1615(35m)\n베이즈 정리, 확률모형 노트 정리(45m)\n\nKOCW 확통 1강 1/2 2040-2120(40m)\n\nCS\n알고리즘 문제 풀기(1H) \ndatastructure0, 1, 2 듣기(30m) 1625-1725(1H)',
#   '5.5H\n\nMath\n확률론, 베이즈정리, 확률모형 노트 정리(1.5H)\nKOCW 확통 1강 듣기\n수학 스터디 코드 정리, 커밋(30m)\n\nCS\n알고리즘 문제 풀기(30m) \ndatastructure2, 3 듣기(30m)\n\nRE\n오답노트 작성\n커밋',
#   'Math 2.5H ★★★★\nKOCW 확통. 본질을 단계적으로 상세하게 설명해준다. \n> 일단 커리큘럼을 따라가보자. \n\nCS 2H ★★★★\n알고리즘 문제를 푸는데 시간이 많이 소요된다. \n> 무작정 붙들고 있기보다, 쉬는 시간마다 틈틈히 볼 수 있도록 하자. \n\ndatastructure 강의. C, C++ 중심으로 implementation한다. \n> python impletation 소스를 따로 구해서 병행 공부해야.\n\n1H으로는 공부시간이 부족하다. \n> 알고리즘, 자료구조 공부에 1H 이상 시간을 투자해야. ',
#   ''],
#  ['',
#   '180608\n\nFRI',
#   '\nMath\nKOCW 확통 1강 1/2 듣기 1130-1219(49m)\nKOCW 확통 2강 듣기 14:10-15:44(1H 34m)\n\nCS\n알고리즘 1225-1300(35m)',
#   '5H\n\nMath\nKOCW 확통 1강 1/2 듣기(1H)\nKOCW 확통 2강 듣기(1.5H)\n\nCS\n알고리즘 문제 풀기(1H) \n자료구조 3, 4, 5강 듣기(1H)\n패키지 트레이닝(30m)\n\nRE\n오답노트 작성 0605 math, cs / 0518 cs\n',
#   'Math ★★★★\nCS ★★',
#   ''],
#  ['',
#   '180609\n\nSAT',
#   '확률변수의 특징값, scipy 복습 1417-1453',
#   '2H\n\nMath\n확률변수의 특징값, scipy 복습\n\nCS\n자료구조 3, 4, 5강 듣기(1H)\n\nRE\n오답노트 작성 0605 math, cs / 0518 cs(1H)\n',
#   'Math ★★★',
#   ''],
#  ['', 'SUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['23',
#   'TOTAL',
#   'Math 8.5H\n미적분, Sympy, 행렬의 미분 복습, 코드 구현(3H)\n수학 오답노트 작성(1H)\n\n선형대수 KOCW 12, 13, 15, 18강 듣기(4.5H)\n\nCS 9H 25m\npandas 과제(4H 10m)\npandas, seaborn 복습(1H)\nHTML 복습, 코드 작성(1H)\n\n오답노트 작성 (1H15m)\n\nedwith 5.인터넷과 네트워크 ~6.HTTP (1H)\n생활코딩 HTML 읽기(1H)\n\nRETRO\nTIL 1회\ngit push 4회',
#   '*HOW\n0.환경 설정 \n- 공부량 유지 : 09:00-22:00. 순수 수련 시간 26H 이상 투자\n- 노트, 교재 구입 : 수학, 플밍 3공 노트 두툼하게.\n\n1.선형대수(하루 2.5H)\n- KOCW 12강 ~ 17강 듣기(~ chapter4)\n- 강의, 교재, 기타 자료(3B1B) 참고해서 개념 숙지\n- 숙지한 개념 스터디 때 직접 설명해보기(주1)\n\n2.자료구조 / 웹(하루 1H)\n- 파이썬 PY4E chapter2 듣기\n- 강의, 교재, 수업, 기타 자료(data structures) 참고해서 개념 숙지 \n\n3.알고리즘\n- 하루 20분, 1문제, 낮은 난이도 문제라도 알고리즘 문제를 풀 수 있도록 시간을 할당한다.\n\n4.수업 복습, 과제, 퀴즈/테스트(2H)\n- 수업 때 배운 수식, 코드는 반드시 직접 연습장에 써본다. 혹은 jupyter notebook으로 구현해본다.\n- 퀴즈, 테스트 결과 갱신. 오답노트 작성하기.(관련 개념 뒷편에 작성하기, 퀴즈 한번 볼 때마다 오답노트 2개 작성하기)\n\n5.적극적으로 수업, 퀴즈, 테스트를 회고한다.(TIL, Daily Commit)\n- 귀가 전 30분, 30분 동안, 패스트캠퍼스에서, 오늘 하루 배운 수학, 플밍 관련 메타데이터를 공유하고(1), 그 핵심 내용을 한줄 요약한다.(2)',
#   'Total \n1.09:00~22:00 동안 잔류하고 순수 26H을 개인 공부에 투자하는 것은 현실적으로 쉽지 않다. \n2.외부 강의의 모든 내용을 전부 훑는 게 불가능하다. 시간이 너무 오래 걸린다. \n\nMath\n\n1.선형대수 하루 2.5H\n- 목표(12~17강)를 달성하지는 못했다. 그러나 Chapter3 핵심 개념을 확실히 이해할 수 있었고, KOCW 등 외부 교보재 활용에 대한 인사이트를 얻었다. \n- 스터디. 박사님 강의를 중심으로, DS에 필요한 핵심 수학 개념을 다질 수 있는 좋은 기회이다. \n\n2.자료구조/웹 하루 1H\n- PY4E 강의는 잘 듣지 않게 된다. 중요하지만, 지금 당장 나에게 필요하지 않기 때문이다. \n- 외부 교보재는 수업을 보충하고 수업을 더욱 심화할 수 있는 것이 좋다. 실제로 다른 수강생은 numpy, pandas 등 패키지 documentation을 참고한다고 했다. \n\n3.알고리즘 X \n- 하루의 일부도 알고리즘 문제 푸는데 사용하지 않았다. \n\n4.수업 복습, 과제, 퀴즈/테스트 \n- 수업 내용 복습, 오답노트 작성 시작. \n- 수업 내용을 온전히 이해하고 체득하지 못했다.(파이썬 패키지 등)\n- CS 복습할 때, 개념을 일일이 쓰고 체화하는 속도가 느리다. 그러나 작은 코드까지 이해할 수 있었다.\n\n- 수업에 한 코드를 단순 반복하는 것으로는 실력이 늘지 않는다. \n- 오답노트 작성은, 과거 배운 내용을 회상하고, 모호한 개념을 확실하게 이해하는 데 도움을 준다.\n오답노트 작성할 때, 오픈북 테스트처럼, 이해/기억하지 못한 개념을 다시 찾아보고 푼 다음 정답과 맞춰보면, 개념에 대해서 한번 더 숙지할 수 있는 것 같다.\n\n5.TIL 1회, git commit 4회',
#   '1.DSS 과정을 온전히 이해하고 체화할 수 있는 방법을 찾아야 한다. \n\n*현재 사용하는, 앞으로 사용할 방법\n- 노트 정리 : 수학, CS의 배운 개념, 내 언어로 다시 쓰기\n- 직접 시도 : 배운 수식, 코드는 연습장, jupyter notebook에 직접 시도하기. \n- 오답 노트(회고) : 퀴즈, 테스트 틀린 문제, 온전히 알지 않고 맞춘 문제 개념 다시 보고 쓰기. \n- 외부 교보재 활용 : KOCW, 생활코딩, edwith 등 강의로 보완. \n\n2.외부 교보재 활용시, 내게 필요한 핵심 개념만 찾아 효율적으로 이해한다. \n\n3.자료구조, 알고리즘은 그 필요성을 당장 체감하진 못하지만, 수많은 사람들이 정진할 필요가 있다고 말하는 분야이다. 방법을 찾아 하루 일정 시간 공부해야 한다. \n\n4.꾸준한 회고, 기록 \n- TIL은 조금 더 가볍게. 모든 내용을 다른 사람이 이해할 수 있도록 적지 않아도 된다. 하루 한 줄이라도 작성할 수 있도록 습관을 들이는 것이 더욱 중요하다.\n- GIT은 지금처럼, 숙제하듯이. '],
#  ['',
#   '180528\n\nMON',
#   '선형대수 KOCW 12강 듣기(1.5H)\n수학 오답노트 작성(50m)\npandas 과제(4H 10m)\nseaborn 복습하기(30m)',
#   '4H 30m\n\n1.선형대수 강의 듣기 : KOCW 12강, 내용 정리. 어려운 내용 교재 참고하기.(2H)\n2.seaborn 복습하기 : 코드 직접 구현하면서, 복습하기(30m)\n3.오답 노트 만들기 : 수학, 플밍 노트 별로 정리(1H 30m)\n4.알고리즘 문제 풀기 : 프로그래머스 level1 2문제(30m)\n5.TIL 작성하기 : 귀가 전 30분, 오늘 하루 수련한 수학, 플밍 관련 메타데이터를 공유(1), 핵심 내용을 한줄 요약(2)\n6.pandas 과제',
#   '7H 투자.\n1.수학, 플밍 공부에 많은 시간을 쏟을 수 있었다. \n2.선형대수는 이대로 꾸준히 하면 되겠다. 매일 강의 1개 듣고, 핵심 개념 이해하는 식으로. \n3.pandas과제. 아직 파이썬 패키지가 손, 머리에 익지 않았다.\n4.다른 수강생은 numpy, pandas 등 패키지 documentation을 참고한다고 했다. \n5.수업에 한 코드를 단순 반복하는 것으로는 실력이 늘지 않는다. \n6.오답노트 작성은, 과거 배운 내용을 회상하는 데 도움을 준다. ',
#   '1.데사스 과정으로, 궁극적으로 무엇을 하려고 하는지 자문자답해야 한다. \n-어느 분야, 어떤 직무에서 일하려고 하는가?\n-어떤 포트폴리오가 필요한가?\n-어떤 프로젝트를 해야 하는가?\n-지금 나는 무엇을 해야 하는가?\n\n2.Toy Problem에 빠지지 않도록 주의해야 한다. 수학, 플밍 공부, 그 자체는 목적이 될 수 없다. 수학 성적이 높다고, 플밍을 잘한다고 자연스레 나의 본 목적이 달성되는 건 아니다. \n\n3.배움의 저변을 넓혀야 한다. 단순히 수업 내용을 복습하는 것만으로는 부족하다. 수업 내용 +a를 공부해야 한다. 단, 내가 시간 투자할 필요가 없는 분야, 직무는 과감하게 포기하고서. \n\n4.기록의 중요성. 기록할 곳은 많다. \n-practice log \n-TIL(hexo)\n-하루 일과(네이버 블로그)\n-코드(깃헙) \n\n결국 기록해야 한다. 어떤 플랫폼에 어떻게 기록할지 생각해보자. '],
#  ['',
#   '180529\n\nTUE',
#   '1.선형대수 강의 듣기 : KOCW 13강(2H)\n',
#   '1.선형대수 강의 듣기 : KOCW 13강, 내용 정리(1.5H)\n2.CS 오답노트 작성(1H)\n3. TIL 작성(hexo) --',
#   '2H 투자. \n\nMath ★★★',
#   ''],
#  ['',
#   '180530\n\nWED',
#   'Math\n미분, Sympy, 미적분 정리(1.5H)\n\nCS\nCS 오답노트 1개 작성(30m)\npandas 개념 정리1(30m)',
#   '\n1.pandas, matplotlib, seaborn 복습 \n2.미분, 미적분 복습\n3.선형대수 KOCW 9-13강 교재 내용 정리\n4.CS 오답노트 작성',
#   '2.5H 투자 \n\nMath\n1.KOCW 강의 교재의 챕터를 전부 훑는 게 불가능하다. 시간이 너무 오래 걸린다. \n\nCS ★★★\n2.퀴즈 오답노트를 정리하니, 모호한 개념을 확실하게 이해할 수 있었다 \n\n3.판다스 복습. 개념을 일일이 쓰고 체화하는 속도가 느리다. 그러나 작은 코드까지 이해할 수 있었다.\n',
#   '1.강의 중심으로 빠르게 넘어가되, 차후 해당 개념이 어려우면 참고하는 것으로. \n2.매일 꾸준히 2개씩(당일 퀴즈 + 예전 퀴즈) 오답노트 작성\n3.전부 다 서술하기보다, 핵심 개념 및 작성법 중심으로 서술. 어떻게 구동되는지를 중심으로. \n'],
#  ['',
#   '180531\n\nTHU',
#   'Math\n행렬의 미분 복습(1H)\n\nCS\n오답노트 작성(0529, 0521) (45m)',
#   '3H\n\nMath\n1.선형대수 KOCW 15강 듣기 \n2.행렬의 미분 복습, 코드 구현\n\nCS\n3.오답노트 2개 작성 \n\n--\n\nTIL \nDaily Commit',
#   '1H45m\n\nCS\n오답노트 작성할 때, 오픈북 테스트처럼, 이해/기억하지 못한 개념을 다시 찾아보고 푼 다음 정답과 맞춰보면, 개념에 대해서 한번 더 숙지할 수 있는 것 같다.',
#   '1.오답노트 작성시 오픈북 테스트처럼. '],
#  ['',
#   '180601\n\nFRI',
#   'Math\n행렬의 미분 복습, 코드 구현(30m)\n오답노트(0531) 작성(10m)\n\nCS\nHTML 복습, 코드 작성(1H)\nedwith 5.인터넷과 네트워크(~4.라우터) 읽기(30m)\n생활코딩 HTML 읽기(1H)',
#   '1.선형대수 15강 듣기 \n2.행렬의 미분 복습, 코드 구현(30m)\n3.HTML, CSS, JS 복습(문서화, 블로그 업로드)\n4.오답노트 4개 작성(2, 3, 18, 31)\n\n--\nTIL, COMMIT',
#   '3H\n\nMath ★★\nKOCW 강의 듣기가 후순위로 밀려난다. 프로젝터를 배울 때보다, 배움의 이유를 찾기 못하기 때문이다. \n\nCS ★★★★\n웹프로그래밍 복습과 더불어, 추가적 개념 숙지 및 실습 필요\n',
#   '1. 시기 별 필요한 핵심 개념만 빠르게 훑고, 상세 내용은 나중에 다시 배우자.\n2. 생활코딩, CS50, 코드카데미 등 다양한 소스 참고해서 보충하도록 하자.'],
#  ['',
#   '180602\n\nSAT',
#   'Math \n선형대수 18강 1/2(30m) \nedwith5 (~6.HTTP) (30m)',
#   '2H\n\nMath \n선형대수 18강 마무리\n3B1B 보기\n\nCS \nedwith 5 마무리 \nCSS 복습(문서화, 블로그 업로드)\n',
#   '',
#   ''],
#  ['',
#   '180603\n\nSUN',
#   '',
#   'HTML, CSS 복습(문서화, 블로그 업로드) > 블로그 수정할 때 응용해보기\n\n선형대수 18강 마무리\n3B1B 보기',
#   '',
#   '1.DSS 과정을 온전히 이해하고 체화할 수 있는 방법을 찾아야 한다. \n\n*현재 사용하는, 앞으로 사용할 방법\n- 노트 정리 : 수학, CS의 배운 개념, 내 언어로 다시 쓰기\n- 직접 시도 : 배운 수식, 코드는 연습장, jupyter notebook에 직접 시도하기. \n- 오답 노트(회고) : 퀴즈, 테스트 틀린 문제, 온전히 알지 않고 맞춘 문제 개념 다시 보고 쓰기. \n- 외부 교보재 활용 : KOCW, 생활코딩, edwith 등 강의로 보완. \n\n2.외부 교보재 활용시, 내게 필요한 핵심 개념만 찾아 효율적으로 이해한다. \n\n3.자료구조, 알고리즘은 그 필요성을 당장 체감하진 못하지만, 수많은 사람들이 정진할 필요가 있다고 말하는 분야이다. 방법을 찾아 하루 일정 시간 공부해야 한다. \n\n4.꾸준한 회고, 기록 \n- TIL은 조금 더 가볍게. 모든 내용을 다른 사람이 이해할 수 있도록 적지 않아도 된다. 하루 한 줄이라도 작성할 수 있도록 습관을 들이는 것이 더욱 중요하다.\n- GIT은 지금처럼, 숙제하듯이. '],
#  ['', '', '', '', '', ''],
#  ['22',
#   'TOTAL',
#   'Math 13.5H\n"NumPy를 활용한 선형대수 입문" 정리(1H)\n"행렬의 성질", "역행렬과 연립방정식", "벡터와 행렬의 연산" 정리(3H 30m)\n"선형대수와 해석기하의 기초", "좌표 변환", "고윳값 분해" 정리(3H 30m)\nKOCW 10, 11강 듣기(3.5H)\n"함수", "SymPy를 활용한 함수 미분", "적분" 복습, 직접 시도(2H)\n\nCS 12.25H\n(과제) numpy 실습(7H)\n클래스, 패키지 복습(30m)\npandas 복습(2H 30m)\nmatplotlib 복습(1H)\n\n알고리즘 5문제(1H)\ndata structure intro 듣기(15m)\n\netc.\nTIL 겸 포스팅 작성. \n',
#   '* HOW\n1.하루 70% 수학, 플밍 공부에 투자. 도메인 지식 유지, 포폴/플젝 준비는 기타 시간을 사용한다.\n2.수업 진도 놓치지 않기. 수업 시간에 최대한 이해하고 응용하되, 부족한 부분은 break day와 평일 저녁 시간을 적극적으로 활용한다.\n3.TIL, 포스팅을 하기 위해서는 매일 일정 시간을 투자하여, 구체적 목표를 달성하는 식으로 이루어져야 한다. 매일 수학, 플밍 관련 TIL을 쓰는 것. \n4.의지보다 구조, 환경을 다잡을 것. 의지만으로 해결될 문제가 아니다.\n\n* WHAT TO DO\n1.수업 \n복습(***) 선형대수1, 2, 3, 미적. 기본 문법, 넘파이, 판다스, 데이터시각화. 깃, 리눅스 등 / 하루 1H(예 30m, 복 30m), 내용 습득. \n\n2.수학\n선형대수(***) : KOCW 강의 하루에 1개씩 5강 듣기(10강 ~ 14강) 교재 읽기, 문제 풀기 / 하루 3H, 개념 이해  중심. 투자시간이 오래 걸리더라도 확실하게 다 잡기. 3B1B 참고\n\n3.플밍\n알고리즘 : 프로그래머스 level 무관하게 2~3문제 꾸준히 풀기 (하루 30m 투자 ***)\nCS, WEB 지식 : Data Structure 강의, 생활코딩 WEB / Database 강의. 하루에 1개씩 5강 듣기.(튜토리얼 - 4강) / 하루 30m 투자.',
#   'Math \n1.핵심 개념을 제대로 익히는 것이 장기적으로 나에게 도움이 될 것이다. \n2.개념을 읽고 되새기고 쓰는 행위는 개념을 더욱 잘 이해할 수 있도록 해준다. \n3.KOCW 선형대수 강의를 듣고, 박사님 강의를 들으니 핵심 개념을 더욱 잘 이해할 수 있었다. 강의로 보완한 부분과 그렇지 않은 부분의 이해도 차이가 크다. \n4.확률과 통계 강의와 겹치지 않도록, 속도를 낼 필요는 있다. \n\nCS\n1.공부량이 절대적으로 적다. \n2.시험을 본 결과 코딩이 익숙하지 않을 뿐만 아니라, 개념 역시 제대로 체화하지 못하고 있었다. \n3.프로그래머스 문제 푸는 데 생각보다 많은 시간이 소요됐다. \n4.CS 수업, 기타 수업(data structure 등)이 쉽게 휘발된다. \n5.따로 개념을 기록하고 암기할 필요가 있다. \n6.직접 하면서 배운 내용을 되새김질하니 효과가 크다.',
#   '1.전체 공부량을 늘린다(유지한다)\n- 최대한 일찍 출근하고 최대한 늦게까지 잔류한다(09:00-22:00)\n- 순수 수련 시간(수학, 플밍만. 수업, 스터디, 프로젝트 X)을 주 26H 이상 투자한다.\n\n2.수학, 플밍 핵심 개념을 체화한다.\n- 수학은 선형대수, 확률론. 플밍은 파이썬, 자료구조, 웹, 데이터베이스. \n- 선형대수 : KOCW / 3B1B / 수업 참고. 스터디 때 배운 개념을 직접 말하면서 인출. \n- 파이썬 / CS : PY4E(datastructure part 위주로) / 윤성우 열혈자료구조 / mycodeschool datastructure 중심으로. *어떻게 인출해야 할지 방법론을 찾아야 한다.\n- 선형대수/확률론/파이썬/자료구조/웹/데이터베이스 등 각 파트 별로 노트를 구입해서 내용을 직접 쓰고, 외우고, 말하면서 체화한다.\n\n3.수식, 코딩에 익숙해진다.\n- 수업 때 배운 수식, 코드는 반드시 직접 연습장에 써본다. 혹은 jupyter notebook으로 구현해본다.\n- 하루 20분, 1문제, 낮은 난이도 문제라도 알고리즘 문제를 풀 수 있도록 시간을 할당한다.\n\n4.적극적으로 수업, 퀴즈, 테스트를 회고한다.(TIL)\n- TIL : 언제(얼마 동안), 어디에서, 어떤 내용을, 구체적으로 어떻게, TIL을 쓸 것인지 정한다.\n- 귀가 전 30분, 30분 동안, 패스트캠퍼스에서, 오늘 하루 배운 수학, 플밍 관련 메타데이터를 공유하고(1), 그 핵심 내용을 한줄 요약한 다음(2), 오늘 느낌을 쓴다(3)\n\n'],
#  ['',
#   '180521\n\nMON',
#   'NumPy를 활용한 선형대수 입문 : 개념 정리(1H)\n벡터와 행렬의 연산 : 개념 정리(1H 30m)\n\n클래스, 패키지(30m)',
#   '4.2H (6H) \n\n[선형대수1,2] 입문(1), 연산(2), 성질(3), 연립방정식/역행렬(3) 개념 읽기, 외우면서 쓰기(3H) \n[파이썬 5,6,7,8,9] 클래스(5), 패키지(6), 예외처리(7), 피클(8), 쓰레드(9) 노트 정리, 개념 적용하기(1H)\n[TIL] 수학, 플밍 중심. ACT 쓰되, 제 3자가 보더라도 이해할 수 있도록 쓰기(30분)\n--\n[알고리즘] 프로그래머스 level2, level1 문제 풀기(30m)\n[블로그] 포스팅. "경청", "개념 확립"의 중요성.',
#   'Total \nTIL을 작성하지 않았다. 월요일의 실천을 회고하지 않았다. \n\nMath \n.시간은 3시간 쏟았지만, 목표의 2 / 3 만 달성할 수 있었다. 다만, 핵심 개념을 제대로 익힐 수 있어 좋았다. 장기적으로 나에게 도움이 될 것이다. \n.개념을 읽고 되새기고 쓰는 행위는 개념을 더욱 잘 이해할 수 있도록 해준다. \n\nCS\n.프로그래머스 문제 1개 도전. 생각보다 많은 시간이 소요됐다. CS 기본 개념을 숙지하는 것과 별개로, 손과 머리가 코딩에 익숙하게끔 하는 작업, 시간이 필요하다는 것을 느꼈다. ',
#   '회고 X'],
#  ['',
#   '180522\n\nTUE',
#   'Math\nT : 코팩터(여인수) 문제를 제외하고 전부 다 잘 쓸 수 있었다. \n행렬의 성질, 역행렬, 선형기하 내용 정리(2H)\n파이썬 기본. \n\nCS\nT : thread 문제를 제외하고 전부 다 잘 쓸 수 없었다. \n\nTIL 겸 포스팅 작성. ',
#   '2H \n\n[linalg] 성질, 역행렬, 선형기하(2H) \n[py] 기본 내용 마무리, numpy 숙제(30m)\n[TIL] 수학, 플밍 중심. 인사이트 적기. \n[포스팅] 개념 확립의 중요성',
#   'Total \n15:00~ 2~3시간 투자. \n\nMath ★★★★\n핵심 내용을 확실하게 익힐 수 있었다. 선형대수 part3를 들을 때, 예전에 배운 개념을 쉽게 기억할 수 있었다. \nKOCW 선형대수 강의를 듣고, 박사님 강의를 들으니 핵심 개념을 더욱 잘 이해할 수 있었다. \n\nCS ★★\n공부량이 절대적으로 적다. \n시험을 본 결과 코딩이 익숙하지 않을 뿐만 아니라, CS 개념 역시 제대로 체화하지 못하고 있었다. ',
#   '1.전체 공부량 늘이기. 평일 주 4회, 9:00 ~ 22:00 FC 잔류.\n2.선형대수 KOCW ch3 강의 듣기 시작. 핵심 개념 중심으로. \n3.CS 기본 개념 숙지하기. CS 자체 커리큘럼 구성. 두진 강사님 강의와 연계할 것. \n4.매일 코딩 익숙해지기. 알고리즘 문제 N개 +a(다른 방법 모색)\n\n'],
#  ['',
#   '180523\n\nWED',
#   'ING \n과제 제출. 알고리즘 7~10, numpy 실습(2H)\n\nMath \n선형대수 part3 "선형대수와 해석기하의 기초" 개념정리(30m)\n\nCS\n과제 제출. 알고리즘 7~10, numpy 실습(5H)\ndata structure intro 듣기(15m)\n',
#   'Total 6.3H / 9H \n\nMath \n선형대수 part3 개념 정리. 코드 적용.(1H) \nKOCW 강의 10, 11강 재정리, 교재 읽기, 문제 풀이(2.5H)\n\nCS \n과제 제출. 알고리즘 7~10, numpy 실습(2H)\n0521 / 0522 오답노트 만들기(30m)\n자료구조. 0, 1강 듣기. 노트에 핵심 개념 정리(30m)\n',
#   'Total 5.75H ★★★★\n\nMath ★★\n선형대수 part3 전부 다 정리하지 못 했다. \n\nCS ★★★★\ndata structure 강의가 영어로 이루어지다보니 쉽게 휘발된다. ',
#   '1.자료구조, 알고리즘, 웹, 데이터베이스 등 중요한 개념은 따로 정리할 필요가 있다. \n2.기계적으로 강의를 듣기보다, 금요일 스터디 때 특정 개념을 설명할 수 있도록, 핵심 개념만 발췌할 수 있도록. '],
#  ['',
#   '180524\n\nTHU',
#   '선형대수 part3 내용 정리 "좌표 변환"\n선형대수 part3 내용 정리 "고윳값 분해"\n(3H)\n\npandas 핵심 내용 복습(2H)\n프로그래머스 알고리즘3문제(30m)',
#   'Total 5.5H \n\nMath \n선형대수 part3 핵심 개념, 박사님 노트 중심으로 살 붙이기. KOCW 강의 및 교재 활용해서 정리(3H)\n\nCS \nnumpy, pandas 복습. 노트에 핵심 개념 정리(2.5H)\n0521 / 0522 오답노트 만들기(30m)\ndata structure 1, 2, 3강 듣기(20m)',
#   'Total 5H ★★★★\n\nMath ★★★★\n선형대수 part3 개념 정리. 그러나 아직 모호한 개념, 증명하지 못한 개념이 많다. \nKOCW 강의로 보완한 부분과 그렇지 않은 부분의 이해도 차이가 크다. \n\nCS ★★★\nCS 수업 내용이 생각보다 쉽게 휘발된다. ',
#   '1.늦더라도 KOCW 강의, 교재로 선형대수를 보완할 필요가 있다.\n2.실전에서 잘 응용할 수 있도록 노트를 마련하여 정리할 필요가 있다. (+ CS50, opentutorials, mycodeschool)'],
#  ['',
#   '180525\n\nFRI',
#   '선형대수 KOCW 10강 핵심 내용 중심으로 듣기, 교재 읽기, 문제 풀기(1.5H)\n\npandas 복습 (30m)\n알고리즘 2문제 (30m)',
#   'Total 4H \n\nMath \n선형대수 KOCW 10강 핵심 내용 중심으로 듣기, 교재 읽기, 문제 풀기(2.5H)\n\nCS \npandas 복습 (30m)\ndata structure 1, 2강 듣기 (30m)\n\n---\n\nTIL \n',
#   'Total 3H ★★★\n\n\nMath ★★★★\n선형대수 KOCW 10강 다시 듣기(1.5H). 박사님 강의로 한번 들은 내용이라 이해가 더욱 쉽다. 동시에, 박사님 강의에서 누락된 부분도 상세하게 들을 수 있다. \n\nCS ★★\npandas 복습. 따로 개념을 기록할 필요가 있다. \n',
#   '1.오답 / 수학(선형대수, 확통) / CS(자료구조, 웹, DB) 내용을 정리할 노트가 필요하다. \n2.pandas 복습. 따로 개념을 기록할 필요가 있다. \n'],
#  ['',
#   '180526\n\nSAT',
#   '선형대수 KOCW 11강 강의 듣기, 교재 읽기 (2H)\n박사님 수업. 함수, 미분, 적분 개념 복습, 직접 해보기(2H)\nmatplotlib 복습(1H)',
#   'Total 3H \n\nMath \n선형대수 KOCW 11강 강의 듣기, 교재 읽기 (2H)\n10강 부분 교재 읽기 \n박사님 수업. 함수, 미분, 적분 개념 복습, 직접 해보기(2H)\n\nCS \npandas 과제(--) \n박사님 교재 참고해서 pandas, matplotlib, seaborn 복습하기(--)\n\n-- \n\n블로그 만들기(TIL)',
#   'Total 5H \n\nMath ★★★★\nprojection vector 개념을 통해, pseudo inverse를 구하는 과정에 대해서 더욱 명확하게 알 수 있어 좋았다. \n확률과 통계 강의와 겹치지 않도록, 속도를 낼 필요는 있다. \n\nCS ★★★\njupyter notebook으로 직접 하면서, 미적분 내용을 되새김질 하니 더욱 좋은 듯. \n',
#   '1.확률과 통계 강의와 겹치지 않도록, 속도를 낼 필요는 있다. \n2.jupyter notebook으로 직접 하면서, 미적분 내용을 되새김질 하니 더욱 좋은 듯. \n'],
#  ['', '', '', '', '', ''],
#  ['21', 'TOTAL', '', '', '', ''],
#  ['', '180514\n\nMON', '', '', '', ''],
#  ['', '180515\n\nTUE', '', '', '', ''],
#  ['', '180516\n\nWED', '', '', '', ''],
#  ['', '180517\n\nTHU', '', '', '', ''],
#  ['', '180518\n\nFRI', '', '', '', ''],
#  ['', '180519\n\nSAT', '', '', '', ''],
#  ['', '180520\n\nSUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['20', 'TOTAL', '', '', '', ''],
#  ['', '180528\n\nMON', '', '', '', ''],
#  ['', '180529\n\nTUE', '', '', '', ''],
#  ['', '180530\n\nWED', 'break week', '', '', ''],
#  ['', '180531\n\nTHU', '', '', '', ''],
#  ['', '180601\n\nFRI', '', '', '', ''],
#  ['', '180602\n\nSAT', '', '', '', ''],
#  ['', '180603\n\nSUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['19', 'TOTAL', '', '', '', ''],
#  ['',
#   '180430\n\nMON',
#   '수업 내용 복습(90m)\nKHAN 확률과통계1,2(102m)\nKHAN 확률과통계3(30m)',
#   '',
#   '-수학 \n(1)KHAN 확률과통계 part1 3H \n\n-플밍 \n(1)수업 내용 복습 1H 30m \n(2)프로그래머스 level1 3문제',
#   '-수학 ★★★\n(1)확률과통계 2.5H\nWISH\n개념서, 문제풀이집이 필요하다 \n\n-플밍 ★★★\n(1)수업 복습 1.5H\nLIKE \n지난 주, 오늘 배운 내용 정리. '],
#  ['',
#   '180501\n\nTUE',
#   'KHAN 확통 4(121m)\nKOCW 선형대수 1강(60m)\nKOCW 선형대수 2강(60m)',
#   '',
#   '-수학\n(1)KHAN 확통 2H\n(2)KOCW 선형대수학 2H \n\n-알고리즘 \n(1)수업 복습\n(1)프로그래머스 level1 2문제 30m',
#   '-수학 4H ★★★★\n(1)KHAN 확통 2H\n(2)KOCW 선형대수 1,2강 2H\n\n-플밍 ★★★\n(1)수업 복습 30m'],
#  ['',
#   '180502\n\nWED',
#   'KOCW 선형대수학3(1H20m)',
#   '',
#   '-수학\nKHAN 확통5,6,7 2H\nKOCW 선형대수학3,4 2H \n\n-플밍 \n수업 복습(30m)\n오답노트 만들기(30m)\n\n',
#   '-수학 1H20m ★★\n(1)KOCW 선형대수 3강 80m\nLIKE: 내용을 놓지 않고 공부할 수 있었다 \nWISH: 체력 관리가 중요하다'],
#  ['',
#   '180503\n\nTHU',
#   '수업 복습(30m)\n오답 노트(30m)\nKHAN 확통5,6(45m, 74m)\nKOCW 선형대수학4(65m)\nKHAN 확통1,2(40m)\nKOCW 선형대수학5(75m)',
#   'KHAN 확통 part1 기초다지기\n',
#   '-수학 \nKOCW 선형대수학4,5 2H \nKHAN 확통 기초 다지기 3H',
#   '-수학 3H ★★★★\nKHAN 확통 part1 마무리(2H)\nKOCW 선형대수4,5(140m)\n\nWISH\n칸아카데미 확통 파트로 개념정리가 쉽지 않다\n> KOCW 강의로 보완 필요\nKOCW 강의 후 문제를 풀면서, 개념을 적용해봐야 한다. \n> 교재 필요\n\n-플밍 ★★★\n수업 복습(30m)\n오답 노트(30m)'],
#  ['',
#   '180504\n\nFRI',
#   'KOCW 선형대수학6(80m)\nKHAN 확통 part1-3(55m)\nKHAN 확통 part1 -8,9(90m)\nKOCW 선형대수학7(81)\n알고리즘 level1 1문제(10m)',
#   '',
#   '-수학\nKOCW 선형대수학6,7(3H)\nKHAN 확통 part1 다지기(2H)\n\n-플밍 \n프로그래머스 알고리즘 level1 5문제(1H)',
#   '-수학 5H ★★★★\nLIKE\n천천히 들으니 이해가 더욱 잘 된다\n감이 온다 \n\n-플밍 ★★★\nLIKE 꾸준히 하기 시작했다'],
#  ['', '180505\n\nSAT', '', '', '', ''],
#  ['', '180506\n\nSUN', '', '', '', ''],
#  ['', '', '', '', '', ''],
#  ['18', 'TOTAL', '', '', '', ''],
#  ['', '180423\n\nMON', '', '', '', ''],
#  ['', '180424\n\nTUE', '', '', '', ''],
#  ['',
#   '180425\n\nWED',
#   '-수학\nTrigonometry 3(48m)\nTrigonometry 4(208m) \nTrigonometry 5(46m)\nprecalculus3 vectors(114m) \nDifferentail Calculus(63m)\n\n-플밍 \nlevel1 1문제(10m)',
#   '',
#   '-수학 KHAN - Trigonometry, Precalculus 다지기(7H). 강의/퀴즈/재풀이 \n(1) Trigonometry 3,4,5 강의 / 퀴즈 (강의 당 1H 목표)\n(2) Precalculus 1,2,3,4 강의 / 퀴즈 ("") \n\n-플밍 프로그래머스. 난이도 확인하기(30m). 손코딩/코딩/재풀이 \n(1) Level1 1문제(30m)',
#   '-수학 KHAN 삼각함수 (7.9H) ★★★★\nLIKE 개념 이해, 원리 적용 속도가 빨라졌다 \nWISH 생각보다 시간이 오래 걸린다 \n\n-플밍 프로그래머스 X. ★★\nWISH 조금씩 시간 안배할 수 있도록 '],
#  ['',
#   '180426\n\nTHU',
#   '-수학\nDifferential Calculus2-6(176m)\nDifferential Equations(123m)\n\n-플밍 \nlevel1 2문제(45m)',
#   '',
#   '-수학 KHAN\n(1) Differential calculus 문제풀이\n(2) Differential Equations 개념 익히기 \n(3) Linear Algebra 개념 익히기(5.5H)\n\n-알고리즘 난이도 업(30m). 손코딩/코딩/재풀이 \n(1) Level1 2문제(30m)',
#   '-수학 KHAN 미분/미분방정식(5H) ★★★★\nLIKE \n미분 개념 이해, 원리 적용 속도가 빨라졌다 \n목표치 근사하게 달성 \n\nWISH \n문제 풀이도 좋지만, 개념도 탄탄하게 정리할 수 있어야 \n밑단부터 차근차근 다지고 다음 파트로 넘어가야\n\n-플밍 프로그래머스 level1(10m) ★★'],
#  ['',
#   '180427\n\nFRI',
#   '-수학 \ndifferential calculus1-6 마무리(143m)\n\n-플밍 \nlevel1 2문제(40m)',
#   '',
#   '-수학 KHAN 3H\n(1) differential calculus 강의, 퀴즈(3H)\n\n-알고리즘 풀기(30m)  \n(1) level1 3문제(30m) 코딩/회고/수정',
#   '-수학 KHAN 미분(약 2.5H) ★★★\nLIKE \n무작정 접근하기보다, 차근차근 생각하면서 풀 수 있게 되었다 \n기초부터 찬찬히 다질 수 있었다 \n\nWISH \n시간 투자를 많이 하지 못했다 \n\n-알고리즘(40m) ★★★\nLIKE\n속도가 조금 더 빨라졌다 \n\nWISH\n한, 두 문제에 시간을 많이 쏟는다\n'],
#  ['',
#   '180428\n\nSAT',
#   '플밍 quiz2 1-6 풀기 코딩/회고/수정',
#   '',
#   '-수학 KHAN \n(1) precalculus 벡터, 행렬 \n\n-플밍 \n(1)quiz2 1-4 풀기 코딩/회고/수정',
#   '-수학 X\n\n-알고리즘(--) 퀴즈풀기 ★★★★★\nLIKE \n많은 시간 동안, 숙고하며 실력을 향상할 수 있었다 \n프로그래밍 후, 회고/수정 과정을 통해 더 나은 코드를 작성할 수 있었다 \n\nWISH \n얼마 만큼 시간이 소요되었는지 고려하지 않았다 \n몇몇 문제는, 구체적으로 설계 후 코딩하지 않고, 무작정 코딩을 시작해서 혼란을 빚었다 '],
#  ['', '180429\n\nSUN', '', '', '', '']]

# %%
# 위치를 지정하여 행렬 형태로 데이터 가져오기
some_data_sheet1 = sheet1.get_values(start=(2,2), end=(3,3), returnas='matrix')
some_data_sheet1
# Out:
# [['석영1', 'syh602@naver.com'], ['석영2', 'syh602@daum.net']]

# %%
# "시트[행][열]"과 같은 방법으로 특정 셀의 데이터를 가져올수 있습니다.
value = sheet1[2][1]
value
# Out:
# '석영2'

# %%
# 문자열 찾기 (C2 - 3번째 열, 2번째 줄)
cell_list = sh[0].find("syh602@gmail.com")
print(cell_list)
# Out:
# [<Cell C4 'syh602@gmail.com'>]

# %%
# 특정 문자열이 있는 셀을 찾아서 다른 문자열로 바꾸기
cell_list = sh[0].find("syh602@gmail.com", replace="jinjingk@gmail.com")
cell_list
# Out:
# [<Cell C4 'jinjingk@gmail.com'>]

# %%
# csv 파일로 export하기
sheet1.export(pygsheets.ExportType.CSV, filename="sheet1.csv")
# Out:
# sheet1.csv

# %% [markdown]
# #### 9. Update & Insert

# %%
# A1에서 C4까지의 위치에 some_data_sheet1 데이터로 업데이트함
# some_data_sheet1에는 [['박두진', 'pdj1224@gmail.com'], ['김상진', 'pdj1224@daum.net']] 데이터가 들어있음으로 4개의 value가 들어감
sh[1].update_cells(crange='A1:C4', values=some_data_sheet1)

# %%
# sh[1] 위치에 있는 두번째 시트에 대한 모든 데이터를 가져옴
all_data_sheet2 = sh[1].get_all_values()
all_data_sheet2
# Out:
# [['석영1', 'syh602@naver.com', '', '', ''],
#  ['석영2', 'syh602@daum.net', '', '', '']]

# %%
# 4번째줄 아래로 2줄 삽입 (5,6번째줄에 데이터 삽입)
sh[1].insert_rows(row=6, number=3, values=all_data_sheet2)

# %%
# 시트의 열과 행을 재설정해줌
sh[1].rows = 10
sh[1].cols = 3

# %%
# 반복문을 통해 한줄씩 읽어 올수 있음
for row in sh[1]:
    print(row)
# Out:
# ['석영1', 'syh602@naver.com', '']
# ['석영2', 'syh602@daum.net', '']
# ['', '', '']
# ['', '', '']
# ['', '', '']
# ['', '', '']
# ['석영1', 'syh602@naver.com', '']

# %%
# 시트의 제목을 업데이트
sh[1].title = "NewSheet"

# %%
# 시트의 마지막 데이터를 찾아 마지막 데이터의 아래에 데이터를 추가
sh[1].append_table(values=["이민성","pdj1224@gmail.com"])

# %%
sh[1].rows
# Out:
# 7

# %%
# 시트 내용 모두 삭제하기
sh[1].clear()

# %% [markdown]
# #### 10. change to pandas
# - google sheet를 데이터 분석을 위한 파이썬 패키지인 pandas의 DataFrame으로 변환할수 있다.

# %%
sheet1
# Out:
# <Worksheet '시트1' index:0>

# %%
df = pd.DataFrame()
df = sheet1.get_as_df()
df
# Out:
#    순번   이름                    이메일
# 0   1  박두진  radajin1224@gmail.com
# 1   2  김상진       pdj1224@daum.net
# 2   3  최윤성      1221pdj@naver.com

# %%
# csv 파일로 저장
df.to_csv("email.csv", index=False)

# %%
# csv 파일 읽어오기
df = pd.read_csv("email.csv")
df
# Out:
#    순번   이름                    이메일
# 0   1  박두진  radajin1224@gmail.com
# 1   2  김상진       pdj1224@daum.net
# 2   3  최윤성      1221pdj@naver.com

# %% [markdown]
# #### 11. Cell

# %%
# sheet1을 cell_test 시트를 만들어 복사한다.
test_sheet = sh.add_worksheet("cell_test", src_worksheet=sheet1)
test_sheet
# Out:
# <Worksheet 'cell_test' index:2>

# %%
# 특정 셀의 객체 가져오기
b2 = test_sheet.cell('B2')

# 셀 값 확인
print(b2.value)
# Out:
# 박두진

# %%
# b2 객체의 3번째 칸의 데이터를 b2에 할당
b2.col = 3

# 셀 값 확인
print(b2.value)
# Out:
# radajin1224@gmail.com

# %%
# b2에 해당하는 위치의 데이터를 "radajin1224@gmail.com"로 바꿈
b2.value = "pdj1224@gmail.com"
b2.value
# Out:
# 'pdj1224@gmail.com'

# %%
# C2 위치의 데이터를 'radajin1224@gmail.com'로 업데이트함
test_sheet.update_cell('C2', 'radajin1224@gmail.com')

# %%
# A1에서 C4의 셀 리스트 가져옴
cell_list = test_sheet.range('A1:C4')
print(cell_list)
# Out:
# [[<Cell A1 '순번'>, <Cell B1 '이름'>, <Cell C1 '이메일'>], [<Cell A2 '1'>, <Cell B2 '박두진'>, <Cell C2 'radajin1224@gmail.com'>], [<Cell A3 '2'>, <Cell B3 '김상진'>, <Cell C3 'pdj1224@daum.net'>], [<Cell A4 '3'>, <Cell B4 '최윤성'>, <Cell C4 '1221pdj@naver.com'>]]

# %%
cell_list[3][2].value
# Out:
# '1221pdj@naver.com'

# %%
# A1에서 C4의 셀 리스트 가져옴
cell_list = test_sheet.get_values('A1','C4', returnas='cells')
print(cell_list)
# Out:
# [[<Cell A1 '순번'>, <Cell B1 '이름'>, <Cell C1 '이메일'>], [<Cell A2 '1'>, <Cell B2 '박두진'>, <Cell C2 'radajin1224@gmail.com'>], [<Cell A3 '2'>, <Cell B3 '김상진'>, <Cell C3 'pdj1224@daum.net'>], [<Cell A4 '3'>, <Cell B4 '최윤성'>, <Cell C4 '1221pdj@naver.com'>]]

# %%
# 두번째 줄의 셀 리스트 가져옴
cell_list = test_sheet.get_row(2, returnas='cells')
print(cell_list)
# Out:
# [<Cell A2 '1'>, <Cell B2 '박두진'>, <Cell C2 'radajin1224@gmail.com'>]

# %%
# %%time
cell = test_sheet.cell('C2')

# 노트 추가
cell.note = "this is email data."

# 셀 배경 색상 변경 (Red, Green, Blue, Alpha
cell.color = (1.0,1.0,0.0,1.0) 

# 텍스트 포멧 변경
cell.text_format['fontSize'] = 12
cell.text_format['bold'] = True

# sync the changes
cell.update()
# Out:
# CPU times: user 132 ms, sys: 7.9 ms, total: 140 ms
# Wall time: 4.23 s

# %% [markdown]
# #### 12. Share

# %%
# add
# 'owner','writer','commenter','reader'
sh.share("radajin1224@gmail.com", role='reader')

# %%
# remove
sh.remove_permissions("radajin1224@gmail.com")
# Out:
# ''

# %% [markdown]
# #### 13. all clear

# %%
sh.del_worksheet(sh[1])

# %% [markdown]
# #### 14. seaborn에서 iris 데이터를 가져와서 구글 데이터 시트에 넣기

# %%
import seaborn as sns
iris = sns.load_dataset("iris")
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
# 새로운 시트 만들기
iris_sheet = sh.add_worksheet("iris")

# %%
iris_sheet.set_dataframe(iris, 'A1', copy_index=True) # (df, cell_start)
