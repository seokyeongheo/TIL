# %%
from selenium import webdriver

# %% [markdown]
# ### Selenium
# - https://www.seleniumhq.org
# - 기본 사용법
# - 파일 업로드
#     - google vision api 웹페이지에 이미지 파일을 업로드, 결과 데이터를 수집
# - 웹데이터 스크래핑
#     - gmarket 페이지 베스트셀러 200 상품 수집
#     - 네이버 본인 계정의 메일 수집
# - 자동화
#     - 특정 워드프레스 사이트의 게시물에 댓글 자동으로 달기
# - 이미지 스크린샷
#     - youtube 영상 이미지를 크롤링
#     - pillow : python에서 이미지 처리에 관련된 패키지

# %% [markdown]
# #### 셀레니움 기본 사용법

# %%
# 브라우져 열기
driver = webdriver.Chrome()

# %%
# 페이지 이동
driver.get("http://naver.com")

# %%
# 윈도우 사이즈 조절
driver.set_window_size(800, 600)

# %%
# 브라우져의 스크롤 조절
script = "window.scrollTo(200,30);"
driver.execute_script(script)

# %%
# 윈도우 객체 저장
main_window = driver.current_window_handle
main_window
# Out:
# 'CDwindow-AE477A21B6C973D94760C102BF1AF951'

# %%
# 윈도우 탭 열기
script = "window.open('http://google.com');"
driver.execute_script(script)

# %%
driver.current_window_handle
# Out:
# 'CDwindow-AE477A21B6C973D94760C102BF1AF951'

# %%
# 현재 열려있는 윈도우 객체 확인
windows = driver.window_handles
windows
# Out:
# ['CDwindow-AE477A21B6C973D94760C102BF1AF951',
#  'CDwindow-30A073E740A94FE8406BE0A49940A958']

# %%
# 현재 윈도우 핸들 변경
driver.switch_to_window(windows[1])

# %%
driver.current_window_handle
# Out:
# 'CDwindow-30A073E740A94FE8406BE0A49940A958'

# %%
driver.switch_to_window(main_window)

# %%
# 페이지 새로고침
scirpt = "location.reload();"
driver.execute_script(scirpt)

# %%
# alert 메시지 처리
scirpt = "alert('selenium test');"
driver.execute_script(scirpt)

# %%
alert = driver.switch_to_alert()
alert.text
# Out:
# 'selenium test'

# %%
alert.accept()

# %%
# confirm 메시지 처리
script = "confirm('dss8')"
driver.execute_script(script)

# %%
confirm = driver.switch_to_alert()
confirm.text
# Out:
# 'dss8'

# %%
# confirm.accept() # 확인 버튼 클릭
confirm.dismiss() # 취소 버튼 클릭

# %%
# input 창에 문자열 입력하기
driver.find_element_by_css_selector("#query")\
.send_keys("패스트 캠퍼스")

# %%
# 클릭 이벤트 발생
driver.find_element_by_css_selector("#search_btn")\
.click()

# %%
# 창닫기
driver.close()

# %%
# 브라우져 닫기
driver.quit()

# %% [markdown]
# #### 파일 업로드
# - google vision api 페이지에 이미지 파일을 업로드
# - iframe으로 이동

# %%
# 구글 비전 api 페이지로 이동
url = "https://cloud.google.com/vision/"
driver = webdriver.Chrome()
driver.get(url)

# %%
# iframe으로 이동
iframe = driver.find_element_by_css_selector\
("#vision_demo_section > iframe")
driver.switch_to_frame(iframe)

# %%
# 메인 프레임으로 돌아가기
# driver.switch_to_default_content()

# %%
# 파일 업로드
# 파일 경로는 절대경로로 작성해주셔야 합니다.
file_path = "/Users/rada/Documents/fastcampus/dss8/04_web/test/dog.png"
driver.find_element_by_css_selector("#input")\
.send_keys(file_path)

# %%
# 웹 데이터 가져오기
driver.find_element_by_css_selector("#webDetection")\
.click()

# %%
web_results = driver.find_elements_by_css_selector\
("#card .container > .row")[:15]
for web_result in web_results:
    print(
    web_result.find_element_by_css_selector(".name")\
    .text,
    web_result.find_element_by_css_selector(".score")\
    .text
    )
# Out:
# French Bulldog 1.28974
# Boston Terrier 1.27957
# Bulldog 1.27812
# Bull Terrier 1.0645
# Soft-coated Wheaten Terrier 0.99607
# Puppy 0.9774
# Border Collie 0.78226
# Terrier 0.6299
# Pet 0.6124
# Brindle 0.5512
# Dog breed 0.4954
# Veterinarian 0.4236
# Breed 0.4157
# Black Brindle 0.3985
# Dog 0

# %%
# 텍스트 데이터 가져오기
driver.find_element_by_css_selector("#fullTextAnnotation")\
.click()

# %%
document_results = driver.find_elements_by_css_selector\
(".page > .container.style-scope.vs-document > fieldset")
len(document_results)
# Out:
# 2

# %%
documents = []
for document_result in document_results:
    words = document_result.find_elements_by_css_selector\
    ('.container .word')
    sentencce_list = []
    for word in words:
        word = word.text.replace(" ","")
        sentencce_list.append(word)
    documents.append(" ".join(sentencce_list))
documents
# Out:
# ['In the dog house', "' 인기를 잃다 , 면목을 잃다"]

# %%
driver.quit()

# %% [markdown]
# #### 스크래핑
# - gmarket 베스트 셀러 데이터를 수집

# %%
url = "http://corners.gmarket.co.kr/Bestsellers"
driver = webdriver.Chrome()
driver.get(url)

# %%
items = driver.find_elements_by_css_selector(".best-list:nth-child(3) > ul > li")
len(items)
# Out:
# 200

# %%
dict_list = []
for item in items:
    dict_list.append({
        "title": item.find_element_by_css_selector('.itemname').text,
        "s-price": item.find_element_by_css_selector('.s-price').text\
        .split(" ")[0].replace(",","")[:-1],
        "o-price": item.find_element_by_css_selector('.o-price').text\
        .split(" ")[0].replace(",","")[:-1],
        "link": item.find_element_by_css_selector('.itemname').get_attribute("href"),
    })
df = pd.DataFrame(dict_list)    
df
# Out:
#                                                   link o-price s-price  \
# 0    http://item.gmarket.co.kr/Item?goodscode=13005...   20000   12900
# 1    http://item.gmarket.co.kr/Item?goodscode=94765...   65900   19900
# 2    http://item.gmarket.co.kr/Item?goodscode=14413...  100000   49900
# 3    http://item.gmarket.co.kr/Item?goodscode=91202...   27100   16900
# 4    http://item.gmarket.co.kr/Item?goodscode=62724...   19500    5900
# 5    http://item.gmarket.co.kr/Item?goodscode=14298...   29000   14900
# 6    http://item.gmarket.co.kr/Item?goodscode=63617...   30000   12900
# 7    http://item.gmarket.co.kr/Item?goodscode=85712...   32900    9900
# 8    http://item.gmarket.co.kr/Item?goodscode=86949...   29600    8900
# 9    http://item.gmarket.co.kr/Item?goodscode=13529...   19200    5900
# 10   http://item.gmarket.co.kr/Item?goodscode=14299...   18900    8900
# 11   http://item.gmarket.co.kr/Item?goodscode=87359...   30000   13900
# 12   http://item.gmarket.co.kr/Item?goodscode=14260...   14900    4500
# 13   http://item.gmarket.co.kr/Item?goodscode=12958...   21400   13900
# 14   http://item.gmarket.co.kr/Item?goodscode=94895...   32900    9900
# 15   http://item.gmarket.co.kr/Item?goodscode=95974...   23000    6900
# 178               [MAC]빠른직구/ 맥/YSL 인기 립스틱/틴트 기획전
# 179      [휴아이지옴므][무료배송] 28~40사이즈 쿨한~여름 전용 슬랙스 3종
# 180              칸타타 아이스커피 190mlx20팩/쟈뎅까페리얼/카페베네
# 181               (1+1)쿨링바지 통바지/아이스슬랙스/반바지 XXL까지
# 182              [단군]G여름신상셔츠/남자남방/헨리넥/7부티셔츠/남자바지
# 183        [신세계푸드]올반키친 육즙짬뽕만두 210g/간식/교자 x10봉/행사
# 184        [무궁화때비누]무궁화 샤워 때비누 900ml 대용량 x2개 + 증정
# 185              [에스오일](S-OIL) 모바일주유권 5만원/ 실시간발송
# 186         삼성 A4 복사용지(A4용지) 75g 2500매 2BOX/더블에이
# 187            [아침농산]현미5kg/백미5kg/찹쌀/찰흑미/발효현미/보리쌀
# 188                  [예작]2018 쿨 썸머 셔츠남방모음전 49종택1
# 189                  원피스/슬랙스/블라우스/스커트/점프수트/린넨원피스
# 190     [매일우유]매일 무지방 0% 멸균우유 200ml x24팩 +줄자증정/우유
# 191                       푸마바디웨어 푸마 드로즈/브라/팬티 택일
# 192            햇 브라질너트 500g+500g 2018.5월 통관 싱싱상품
# 193                  모링가 그라비올라 3일추가할인/분말/잎/티백/비누
# 194                     여름 로브가디건.롱가디건.쉬폰가디건.숄가디건
# 195   [비버리힐스폴로클럽]1매3400원/드로즈/사각/팬티/남성/남자/세트/면/속옷
# 196              [요즘에]여름신상/청바지/슬랙스/반바지/마/7부/빅사이즈
# 197  [데싱디바][DASHING DIVA] 데싱디바 페디큐어 최신상 프리미엄 에디션
# 198       [휴스톰]듀얼라이팅 무선 물걸레청소기 HS-9000 TV CF동일상품
# 199                 G린넨팬츠/마반바지/커플반바지/커플린넨반바지/12색
#
# [200 rows x 4 columns]

# %%
is_nodata = df["o-price"] == ""
df["o-price"][is_nodata]
# Out:
# 19
# 24
# 38
# 56
# 65
# 84
# 96
# 98
# 104
# 122
# 134
# 144
# 162
# 168
# Name: o-price, dtype: object

# %%
df["s-price"][is_nodata]
# Out:
# 19      7000
# 24     39800
# 38     11800
# 56     53000
# 65     39500
# 84      7900
# 96      7000
# 98     19800
# 104    20900
# 122     6900
# 134     6900
# 144    23220
# 162    24500
# 168    11900
# Name: s-price, dtype: object

# %%
df["o-price"][is_nodata] = df["s-price"][is_nodata]

# %%
df
# Out:
#                                                   link o-price s-price  \
# 0    http://item.gmarket.co.kr/Item?goodscode=13005...   20000   12900
# 1    http://item.gmarket.co.kr/Item?goodscode=94765...   65900   19900
# 2    http://item.gmarket.co.kr/Item?goodscode=14413...  100000   49900
# 3    http://item.gmarket.co.kr/Item?goodscode=91202...   27100   16900
# 4    http://item.gmarket.co.kr/Item?goodscode=62724...   19500    5900
# 5    http://item.gmarket.co.kr/Item?goodscode=14298...   29000   14900
# 6    http://item.gmarket.co.kr/Item?goodscode=63617...   30000   12900
# 7    http://item.gmarket.co.kr/Item?goodscode=85712...   32900    9900
# 8    http://item.gmarket.co.kr/Item?goodscode=86949...   29600    8900
# 9    http://item.gmarket.co.kr/Item?goodscode=13529...   19200    5900
# 173        뉴땡큐 3겹 데코 30롤 x 2팩 / 60롤 / 화장지 / 휴지 g
# 174         [닥터웰](한정특가) 콕콕 저주파마사지기 HDW-300/저주파패드
# 175      [종근당 건강]락토핏생유산균골드 3통 (150일분) 구매율 섭취율 1등
# 176                  시어서커 홑이불 여름이불세트 여름침구 여름패드세트
# 177       [더블에이]더블에이 A4 복사용지 80g 4000매 2BOX/A4용지
# 178               [MAC]빠른직구/ 맥/YSL 인기 립스틱/틴트 기획전
# 179      [휴아이지옴므][무료배송] 28~40사이즈 쿨한~여름 전용 슬랙스 3종
# 180              칸타타 아이스커피 190mlx20팩/쟈뎅까페리얼/카페베네
# 181               (1+1)쿨링바지 통바지/아이스슬랙스/반바지 XXL까지
# 182              [단군]G여름신상셔츠/남자남방/헨리넥/7부티셔츠/남자바지
# 183        [신세계푸드]올반키친 육즙짬뽕만두 210g/간식/교자 x10봉/행사
# 184        [무궁화때비누]무궁화 샤워 때비누 900ml 대용량 x2개 + 증정
# 185              [에스오일](S-OIL) 모바일주유권 5만원/ 실시간발송
# 186         삼성 A4 복사용지(A4용지) 75g 2500매 2BOX/더블에이
# 187            [아침농산]현미5kg/백미5kg/찹쌀/찰흑미/발효현미/보리쌀
# 188                  [예작]2018 쿨 썸머 셔츠남방모음전 49종택1
# 189                  원피스/슬랙스/블라우스/스커트/점프수트/린넨원피스
# 190     [매일우유]매일 무지방 0% 멸균우유 200ml x24팩 +줄자증정/우유
# 191                       푸마바디웨어 푸마 드로즈/브라/팬티 택일
# 192            햇 브라질너트 500g+500g 2018.5월 통관 싱싱상품
# 193                  모링가 그라비올라 3일추가할인/분말/잎/티백/비누
# 194                     여름 로브가디건.롱가디건.쉬폰가디건.숄가디건
# 195   [비버리힐스폴로클럽]1매3400원/드로즈/사각/팬티/남성/남자/세트/면/속옷
# 196              [요즘에]여름신상/청바지/슬랙스/반바지/마/7부/빅사이즈
# 197  [데싱디바][DASHING DIVA] 데싱디바 페디큐어 최신상 프리미엄 에디션
# 198       [휴스톰]듀얼라이팅 무선 물걸레청소기 HS-9000 TV CF동일상품
# 199                 G린넨팬츠/마반바지/커플반바지/커플린넨반바지/12색
#
# [200 rows x 4 columns]

# %%
# 할인율 컬럼 추가하기 (소수점 없이 (ex: 27%))
# object로 되어 있는 series를 int로 형변환하여 할인율을 구합니다.
df["discount_rate"] = round(1 - df["s-price"].astype("int") / df["o-price"].astype("int"), 2) * 100
# 소수점 (.0) 제거
df["discount_rate"] = df["discount_rate"].astype("int")
# % 추가
df["discount_rate"] = df["discount_rate"].astype("str")
df["discount_rate"] += "%"
df
# Out:
#                                                   link o-price s-price  \
# 0    http://item.gmarket.co.kr/Item?goodscode=13005...   20000   12900
# 1    http://item.gmarket.co.kr/Item?goodscode=94765...   65900   19900
# 2    http://item.gmarket.co.kr/Item?goodscode=14413...  100000   49900
# 3    http://item.gmarket.co.kr/Item?goodscode=91202...   27100   16900
# 4    http://item.gmarket.co.kr/Item?goodscode=62724...   19500    5900
# 5    http://item.gmarket.co.kr/Item?goodscode=14298...   29000   14900
# 27           [요즘에]여름신상 역대급특가/반바지/치마/슬랙스/청바지/SALE           70%
# 28                         [숏핑] 우리쌀 증편피자 10팩(3종)           25%
# 29                       언니드랑 블라우스/원피스/팬츠/스커트/린넨           70%
# ..                                           ...           ...
# 170           [비너스]비비안외 브라팬티세트/A-F컵/여성속옷/여자/빅사이즈           70%
# 171         [첨이첨이]아동팬티5매4900원특가/유아/런닝/순면/속옷/무료배송           69%
# 172              무료배송 국내생산 종이컵 2000개 1Box/특별기획상품           20%
# 173        뉴땡큐 3겹 데코 30롤 x 2팩 / 60롤 / 화장지 / 휴지 g           52%
# 174         [닥터웰](한정특가) 콕콕 저주파마사지기 HDW-300/저주파패드           64%
# 175      [종근당 건강]락토핏생유산균골드 3통 (150일분) 구매율 섭취율 1등            7%
# 176                  시어서커 홑이불 여름이불세트 여름침구 여름패드세트           78%
# 177       [더블에이]더블에이 A4 복사용지 80g 4000매 2BOX/A4용지           10%
# 178               [MAC]빠른직구/ 맥/YSL 인기 립스틱/틴트 기획전           10%
# 179      [휴아이지옴므][무료배송] 28~40사이즈 쿨한~여름 전용 슬랙스 3종            7%
# 180              칸타타 아이스커피 190mlx20팩/쟈뎅까페리얼/카페베네           45%
# 181               (1+1)쿨링바지 통바지/아이스슬랙스/반바지 XXL까지           70%
# 182              [단군]G여름신상셔츠/남자남방/헨리넥/7부티셔츠/남자바지           70%
# 183        [신세계푸드]올반키친 육즙짬뽕만두 210g/간식/교자 x10봉/행사           27%
# 184        [무궁화때비누]무궁화 샤워 때비누 900ml 대용량 x2개 + 증정           34%
# 185              [에스오일](S-OIL) 모바일주유권 5만원/ 실시간발송            4%
# 186         삼성 A4 복사용지(A4용지) 75g 2500매 2BOX/더블에이           15%
# 187            [아침농산]현미5kg/백미5kg/찹쌀/찰흑미/발효현미/보리쌀           55%
# 188                  [예작]2018 쿨 썸머 셔츠남방모음전 49종택1           34%
# 189                  원피스/슬랙스/블라우스/스커트/점프수트/린넨원피스           70%
# 190     [매일우유]매일 무지방 0% 멸균우유 200ml x24팩 +줄자증정/우유           40%
# 191                       푸마바디웨어 푸마 드로즈/브라/팬티 택일           70%
# 192            햇 브라질너트 500g+500g 2018.5월 통관 싱싱상품            4%
# 193                  모링가 그라비올라 3일추가할인/분말/잎/티백/비누            4%
# 194                     여름 로브가디건.롱가디건.쉬폰가디건.숄가디건           70%
# 195   [비버리힐스폴로클럽]1매3400원/드로즈/사각/팬티/남성/남자/세트/면/속옷           70%
# 196              [요즘에]여름신상/청바지/슬랙스/반바지/마/7부/빅사이즈           70%
# 197  [데싱디바][DASHING DIVA] 데싱디바 페디큐어 최신상 프리미엄 에디션           10%
# 198       [휴스톰]듀얼라이팅 무선 물걸레청소기 HS-9000 TV CF동일상품            5%
# 199                 G린넨팬츠/마반바지/커플반바지/커플린넨반바지/12색           70%
#
# [200 rows x 5 columns]

# %%
driver.quit()

# %% [markdown]
# #### 워드프레스 사이트에 댓글 쓰기
# - 2개의 계정, 2개의 메시지를 2개의 게시글에 자동으로 작성
# - https://radajin661456067.wordpress.com/

# %%
# 페이지 열기
url = "https://radajin661456067.wordpress.com/"
driver = webdriver.Chrome()
driver.get(url)

# %%
# 게시물 링크 가져오기
links = []
articles = driver.find_elements_by_css_selector("#main > article")
for article in articles:
    links.append(
        article.find_element_by_css_selector(".entry-title > a").get_attribute("href")
    )
links
# Out:
# ['https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/',
#  'https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/']

# %%
# 링크로 이동
driver.get(links[0])

# %%
# 스크롤 내리기
script = "window.scrollTo(0, 10000)"
driver.execute_script(script)

# %%
# 댓글창 클릭
driver.find_element_by_css_selector("#comment-form-comment").click()

# %%
# 댓글 내용 작성
driver.find_element_by_css_selector("#comment").send_keys("데이터 사이언스 스쿨 8기")

# %%
# 스크롤 내리기
script = "window.scrollTo(0, 10000)"
driver.execute_script(script)

# %%
# 이메일과 이름 넣기
import time
time.sleep(3)
driver.find_element_by_css_selector("#email").clear()
driver.find_element_by_css_selector("#email").send_keys("1221pdj@naver.com")
time.sleep(1)
driver.find_element_by_css_selector("#author").clear()
driver.find_element_by_css_selector("#author").send_keys("park")

# %%
# 댓글 작성 버튼 클릭
driver.find_element_by_css_selector("#comment-submit").click()

# %%
driver.quit()

# %%
def write_comment(driver, link, msg, email, name):
    driver.get(link)
    script = "window.scrollTo(0, 10000)"
    driver.execute_script(script)
    time.sleep(3)
    driver.find_element_by_css_selector("#comment-form-comment").click()
    driver.find_element_by_css_selector("#comment").send_keys(msg)
    script = "window.scrollTo(0, 10000)"
    driver.execute_script(script)
    time.sleep(1)
    driver.find_element_by_css_selector("#email").clear()
    driver.find_element_by_css_selector("#email").send_keys("1221pdj@naver.com")
    time.sleep(1)
    driver.find_element_by_css_selector("#author").clear()
    driver.find_element_by_css_selector("#author").send_keys("park")
    script = "window.scrollTo(0, 10000)"
    driver.execute_script(script)
    time.sleep(1)
    driver.find_element_by_css_selector("#comment-submit").click()

# %%
links
# Out:
# ['https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/',
#  'https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/']

# %%
driver = webdriver.Chrome()
write_comment(driver, links[0], "한국 축구 화이팅!", "1221pdj@naver.com", "park")
driver.quit()

# %%
driver.quit()

# %%
users = [
    {"email":"1221pdj@naver.com", "name":"park"},
    {"email":"pdj1224@daum.net", "name":"lee"},
]
msgs = ["한국축구 이대로 좋은가?", "멕시코전은 꼭 열심히 하길..."]

driver = webdriver.Chrome()

for user in users:
    for msg in msgs:
        for link in links:
            print(user["email"], msg, end=" - ")
            try:
                write_comment(driver, link, msg, user["email"], user["name"])
                print("성공")
            except:
                print("실패")
                
            time.sleep(1)
# Out:
# 1221pdj@naver.com 한국축구 이대로 좋은가? - 성공
# 1221pdj@naver.com 한국축구 이대로 좋은가? - 성공
# 1221pdj@naver.com 멕시코전은 꼭 열심히 하길... - 성공
# 1221pdj@naver.com 멕시코전은 꼭 열심히 하길... - 성공
# pdj1224@daum.net 한국축구 이대로 좋은가? - 성공
# pdj1224@daum.net 한국축구 이대로 좋은가? - 성공
# pdj1224@daum.net 멕시코전은 꼭 열심히 하길... - 성공
# pdj1224@daum.net 멕시코전은 꼭 열심히 하길... - 성공

# %%
driver.quit()

# %% [markdown]
# #### 네이버 메일 크롤링
# - 네이버 페이로 이동
# - 아이디 패스워드로 로그인
# - 전체 메일수, 안읽은 메일수
# - 메일 제목과 요약을 데이터 프레임으로 만들기

# %%
main_url = "http://naver.com"
mail_url = "http://mail.naver.com"

# %%
# 네이버 페이지 이동
driver = webdriver.Chrome()
driver.get(main_url)

# %%
with open("pw.plk", "wb") as f:
    pickle.dump("1234", f)

# %%
pw = pickle.load(open("pw.plk", "rb"))
pw
# Out:
# '1234'

# %%
pw = pickle.load(open("../test/pw.plk", "rb"))

# %%
# 아이디 패스워드 입력
driver.find_element_by_css_selector("#id").send_keys("1221pdj")
driver.find_element_by_css_selector("#pw").send_keys(pw)

# %%
# 로그인 버튼 클릭
driver.find_element_by_css_selector("span.btn_login > input[type=submit]").click()

# %%
# 메일 페이지로 이동
driver.get(mail_url)

# %%
# 전체 메일 갯수 가져오기
total_mail_count = driver.find_element_by_css_selector("#headTotalNum").text
total_mail_count
# Out:
# '337'

# %%
# 안읽은 메일 갯수 가져오기
unread_mail_count = driver.find_element_by_css_selector("#headUnreadNum").text
unread_mail_count
# Out:
# '326'

# %%
# 메일 데이터 가져오기 - 제목, 보낸사람, 메일링크
mails = driver.find_elements_by_css_selector(".mailList > li")
df = pd.DataFrame(columns=["제목","보낸사람","메일링크"])
for mail in mails:
    title = mail.find_element_by_css_selector(".mail_title").text
    name = mail.find_element_by_css_selector(".name").text
    link = mail.find_element_by_css_selector(".subject > a").get_attribute("href")
    df.loc[len(df)] = {"제목":title, "보낸사람":name, "메일링크":link}
df
# Out:
#                                                    제목                   보낸사람  \
# 0             트위터에서 김용민, 고발뉴스 이상호 기자, Mnet님을 팔로우해보세요!                    트위터
# 1   난장이를위한변명 님이 트윗함: [단독] 재일교포 여배우 A씨 "조재현에게 화장실에서...                    트위터
# 2   종로구에 있는 사람들이 "인공지능, 사람과 토론하는 단계까지 발전했다"을(를) 공유...                    트위터
# 3   트위터에서 JTBC 뉴스, 뉴스타파(Newstapa)-KCIJ, 문성근님을 팔로우해...                    트위터
# 4      트위터에서 SNOWPEACH❄, 강풀, SMTOWN GLOBAL님을 팔로우해보세요!                    트위터
# 5   종로구에 있는 사람들이 "신문배달 소년, 美 메이저 신문 오너 되다"을(를) 공유했...                    트위터
# 6                               (광고) 삼성 4K UHDTV 49만원                   중고나라
# 7   hj 님이 트윗함: 강배전 베리스트롱은 (제 기준) 천상계의 맛입니다. 가면 절대 ...                    트위터
# 8                  트위터에서 자까, EXO, 대한민국 청와대님을 팔로우해보세요!                    트위터
# 9                (광고) 주식투자 VIP종목 선착순 무료 받기! (100명 한정)                   중고나라
# 10  종로구에 있는 사람들이 "반려견과 제주 바다에서 수영? 올해부턴 안 됩니다"을(를)...                    트위터
# 11  (광고)주식. 최소한의 노력으로 고급정보를 얻어보세요 진짜를 구별할수있는 통찰력이 ...                    히어로
# 12  종로구에 있는 사람들이 "한국과학소설작가연대 입장문 (문서번호 2018-정관-3-0...                    트위터
# 13                     (광고) 혈관건강/혈압조절 이제는 이걸로 관리하세요 .                혈압조절파트너
# 14                                      파일 전송 테스트 pdj  radajin1224@gmail.c..
# 15                                        SMTP 테스트 제목  radajin1224@gmail.c..
# 16                             SMTP Send Text 테스트(제목)   hyeshinoh@gmail.co..
# 17                                        SMTP 테스트 제목  radajin1224@gmail.c..
# 18                             SMPT Send Text 테스트(제목)  radajin1224@gmail.c..
# 19                             SMPT Send Text 테스트(제목)  radajin1224@gmail.c..
# 20                                        SMTP 테스트 제목  radajin1224@gmail.c..
# 21                                        SMTP 테스트 제목      hms8619@gmail.com
# 22                                        SMTP 테스트 제목  radajin1224@gmail.c..
# 23                             SMTP Send Text 테스트(제목)   hyeshinoh@gmail.co..
# 24                          (광고) 삼성 태블릿, 애플iPad 13만9천                   중고나라
# 25  트위터에서 BTS JAPAN OFFICIAL, 심상정, 정청래와 더불어민주당님을 팔...                    트위터
# 26                 (광고) [보고서] "2018 물 산업 현황과 사업전망" 출간                산업경제리서치
# 27  변영주 님이 트윗함: “난 전쟁때 나로 인해 죽은 그 사람, 나의 외면으로 인해 죽...                    트위터
# 28  종로구에 있는 사람들이 ""DEPARTURES (20th edit)" from #g...                    트위터
# 29               트위터에서 표창원, 인스티즈 연예소식, 주진우님을 팔로우해보세요!                    트위터
# 30  (광고) 요즘 뜨고있는 창업아이템. 성공창업을 위한 무점포1인창업과 창업정보 및 다...                   창업신문
# 31   (광고) [국비지원 무료교육] 신재생에너지 발전설비기사 자격시험 안내 및 무료자료 제공                 신재생에너지
# 32                            (광고) 삼성 소장가치 노트북 48% 할인                   중고나라
# 33  sichmoon 님이 트윗함: 김부선 딸 이미소 "증거는 가해자가 결백을 입증하기 ...                    트위터
# 34  beaver 님이 트윗함: 산재 쉽지 않겠지만 꼭 산재 인정 받으셨으면 좋겠다.. ...                    트위터
# 35  종로구에 있는 사람들이 "마음이 너무 아파요. 이젠 내가 또 다른 누군갈 좋아할 수...                    트위터
# 36               (광고) 태그호이어, 해밀턴 포함 정품시계 랜덤박스 39,000원                   중고나라
# 37          트위터에서 hitman, M COUNTDOWN, 노회찬님을 팔로우해보세요!                    트위터
# 38  고양이와 술, 음악이 세상을 구원하리 님이 트윗함: 현재 다음 뉴스 1위 기사. 제...                    트위터
# 39  종로구에 있는 사람들이 "≪일다≫ 비난과 낙인 속의 사람들, HIV감염인"을(를) ...                    트위터
# 40          트위터에서 BT21, 방탄소년단공식쇼핑몰, V LIVE님을 팔로우해보세요!                    트위터
# 41  종로구에 있는 사람들이 "Opinion | A note to readers"을(를)...                    트위터
