# %%
from selenium import webdriver

# %% [markdown]
# ### Selenium
#
# - 목적 / 장점
#     - 셀레니움은 브라우져를 자동화하는 툴. 웹 어플리케이션을 자동화하는 목적으로 만들어졌다.
#     - 웹 기반 작업들을 자동화하여 업무 효율성을 높일 수 있다.
#
#
# - 목차
#     - 기본 사용법
#     - 파일 업로드 / 다운로드 : google vision api 웹페이지에서 실습
#     - 스크래핑 : gmarket 베스트셀러 200 아이템 정보 수집, 네이버 메일 데이터 수집
#     - 자동화 : 워드프레스 블로그에 자동으로 댓글 작성
#     - Selenium을 이용한 이미지 스크린 샷 :
#         - youtube 페이지로 실습
#         - pillow 사용 : 파이썬 이미지 처리 패키지
#
#     - 과제 : 네이버 기사 크롤링

# %% [markdown]
# ### 크롬 드라이버 사용법
#
# - 전역에 설정
# - 같은 폴더에 드라이버 파일 두기
# - path 설정

# %%
# 드라이버 실행

driver = webdriver.Chrome()

# %%
# 페이지 이동
# driver는 browser 오브젝트라 할 수 있다.

driver.get("http://www.naver.com")

# %%
# 브라우져의 윈도우 사이즈 조절
# 반응형 웹페이지에서 사용. 

driver.set_window_size(400, 200) # (가로, 세로)

# %%
# 스크롤 조절

script = "window.scrollTo(10000, 1);"
driver.execute_script(script)

# %%
# 현재 윈도우 객체를 저장

main_window = driver.current_window_handle
main_window
# Out:
# 'CDwindow-9888EE412265769020ED323E7207CEFE'

# %%
# 새로운 윈도우 탭 열기

script = "window.open('http://google.com');"
driver.execute_script(script)

# %%
driver.current_window_handle
# Out:
# 'CDwindow-9888EE412265769020ED323E7207CEFE'

# %%
# 윈도우 탭 객체 확인 : 열려 있는 윈도우를 보여준다

windows = driver.window_handles
windows
# Out:
# ['CDwindow-9888EE412265769020ED323E7207CEFE',
#  'CDwindow-27E0042C313DFDC89081CF532B2A6B93']

# %%
# 현재 윈도우 탭 설정

driver.switch_to_window(windows[1])

# %%
driver.switch_to_window(main_window)

# %%
# 페이지 새로고침

script = "location.reload();"
driver.execute_script(script)

# %%
# alert

script = "alert('data science');"
driver.execute_script(script)

# %%
alert = driver.switch_to_alert()
alert.text
# Out:
# 'data science'

# %%
alert.accept()

# %%
# confirm

script = "confirm('test selenium');"
driver.execute_script(script)

# %%
confirm = driver.switch_to_alert()
confirm.text
# Out:
# 'test selenium'

# %%
confirm.dismiss() # 취소 버튼 클릭
# confirm.accept() # 확인 버튼 클릭

# %%
# input 엘리먼트에 문자열 입력하기, 버튼 클릭하기 

# driver.find_elements : select와 유사하다
# driver.find_element : select_one과 유사하다

driver.find_element_by_css_selector("#query").send_keys("패스트캠퍼스")
driver.find_element_by_css_selector("#search_btn").click()

# %%
# 현재 윈도우 닫기

driver.close()

# %%
# 브라우져 닫기

driver.quit()

# %% [markdown]
# ### _파일 업로드_
#
# - google vision api 페이지 활용
# - iframe으로 frame을 수정
# - 이미지 파일을 업로드
# - 웹데이터와 도큐먼트 데이터를 수집한다

# %%
# 구글 비전 api 페이지 이동

url = "https://cloud.google.com/vision/"
driver = webdriver.Chrome()
driver.get(url)

# %%
# iframe 영역으로 변경
# iframe 영역으로 변경하지 않으면 element가 없다는 메시지가 나온다

iframe = driver.find_element_by_css_selector("#vision_demo_section > iframe")
driver.switch_to_frame(iframe)

# %%
# 메인 프레임으로 변경

# driver.switch_to_default_content()

# %%
# 파일 업로드
# 파일 경로를 쓸 때는 "절대경로"로 사용해야 한다.

file_path = "/Users/quartz/Dropbox/TIL/04_web/dog.png"
driver.find_element_by_css_selector("#input").send_keys(file_path)

# %%
# 웹 데이터 가져오기

driver.find_element_by_css_selector("#webDetection").click()

# %%
results = driver.find_elements_by_css_selector("#card > .container > .row")[:5]
results

for result in results:
    print(result.find_element_by_css_selector('.name').text, \
          result.find_element_by_css_selector('.score').text)
# Out:
# French Bulldog 1.29174
# Bulldog 1.27976
# Boston Terrier 1.27667
# Soft-coated Wheaten Terrier 1.01785
# Bull Terrier 0.97157

# %%
# 웹 데이터 긁어오기

results = driver.find_elements_by_css_selector("#card > .container > .row")[:15]

for result in results:
    print(result.find_element_by_css_selector('.name').text, \
          result.find_element_by_css_selector('.score').text)
# Out:
# French Bulldog 1.29047
# Boston Terrier 1.28066
# Bulldog 1.27885
# Bull Terrier 1.07139
# Soft-coated Wheaten Terrier 0.98682
# Puppy 0.8898
# Border Collie 0.78608
# Terrier 0.6546
# Pet 0.6301
# Brindle 0.5639
# Dog breed 0.4977
# Breed 0.4297
# Veterinarian 0.4175
# Black Brindle 0.4112
# Dog 0

# %%
# 문자열 데이터 가져오기

driver.find_element_by_css_selector("#fullTextAnnotation").click()

# %%
fieldsets = driver.find_elements_by_css_selector(".page > \
.container.style-scope.vs-document > fieldset")
len(fieldsets)
# Out:
# 2

# %%
documents = [] # 문장 2개가 들어간다

for fieldset in fieldsets:
    words = fieldset.find_elements_by_css_selector(".container .word")
    word_list = []
    for word in words:
        word = word.text.replace(" ", "")
        word_list.append(word)
    documents.append(" ".join(word_list))
    
documents
# Out:
# ['In the dog house', "' 인기를 잃다 , 면목을 잃다"]

# %%
driver.quit()

# %% [markdown]
# ### _스크래핑_
#
# - gmarket 베스트셀러 아이템 200개

# %%
from selenium import webdriver

# %%
import numpy as np
import pandas as pd

# %%
url = "http://corners.gmarket.co.kr/Bestsellers"
driver = webdriver.Chrome()
driver.get(url)

# %%
items = driver.find_elements_by_css_selector(".best-list:nth-child(3) > ul > li")
type(items)
# Out:
# list

# %%
driver.quit()

# %%
dict_list = []
for item in items:
    dict_list.append({
        "title": item.find_element_by_css_selector('.itemname').text,
        "s-price": item.find_element_by_css_selector('.s-price').text\
        .split(" ")[0].replace(",","")[:-1],
        "o-price": item.find_element_by_css_selector('.o-price').text\
        .split(" ")[0].replace(",","")[:-1],
        "link": item.find_element_by_css_selector('.itemname').get_attribute("href"),
    })
df = pd.DataFrame(dict_list)    
df
# Out:
#                                                   link o-price s-price  \
# 0    http://item.gmarket.co.kr/Item?goodscode=12775...   26300    7900
# 1    http://item.gmarket.co.kr/Item?goodscode=14425...   80000   29900
# 2    http://item.gmarket.co.kr/Item?goodscode=14283...   29900   13900
# 3    http://item.gmarket.co.kr/Item?goodscode=88173...   15000    5900
# 4    http://item.gmarket.co.kr/Item?goodscode=11552...   21600    6500
# 5    http://item.gmarket.co.kr/Item?goodscode=16609...   25900    7900
# 6    http://item.gmarket.co.kr/Item?goodscode=35350...   26300    7900
# 7    http://item.gmarket.co.kr/Item?goodscode=75124...   19600    5900
# 8    http://item.gmarket.co.kr/Item?goodscode=90810...   14000   10000
# 9    http://item.gmarket.co.kr/Item?goodscode=67170...   39000   14900
# 10   http://item.gmarket.co.kr/Item?goodscode=67170...   30000    9900
# 11   http://item.gmarket.co.kr/Item?goodscode=92577...   37900   31900
# 12   http://item.gmarket.co.kr/Item?goodscode=12752...   32900    9900
# 13   http://item.gmarket.co.kr/Item?goodscode=68114...   21000   11900
# 14   http://item.gmarket.co.kr/Item?goodscode=89652...   19600    5900
# 15   http://item.gmarket.co.kr/Item?goodscode=20804...   29800   16500
# 16   http://item.gmarket.co.kr/Item?goodscode=19755...   32900    9900
# 17   http://item.gmarket.co.kr/Item?goodscode=53354...   28000    8900
# 18   http://item.gmarket.co.kr/Item?goodscode=54605...   25900    7900
# 19   http://item.gmarket.co.kr/Item?goodscode=12165...   24900   20900
# 20   http://item.gmarket.co.kr/Item?goodscode=94636...   23000    6900
# 21   http://item.gmarket.co.kr/Item?goodscode=83569...   19500    5900
# 22   http://item.gmarket.co.kr/Item?goodscode=90063...   33000    9900
# 23   http://item.gmarket.co.kr/Item?goodscode=15247...   38400   32900
# 24   http://item.gmarket.co.kr/Item?goodscode=77775...   50000   15900
# 25   http://item.gmarket.co.kr/Item?goodscode=81574...   79500   15900
# 26   http://item.gmarket.co.kr/Item?goodscode=33639...   23000    6900
# 27   http://item.gmarket.co.kr/Item?goodscode=13987...           11800
# 28   http://item.gmarket.co.kr/Item?goodscode=89029...   24000   13900
# 29   http://item.gmarket.co.kr/Item?goodscode=77724...   32900    9900
# ..                                                 ...     ...     ...
# 170  http://item.gmarket.co.kr/Item?goodscode=15800...   30000   17500
# 171  http://item.gmarket.co.kr/Item?goodscode=89679...   25000   20500
# 172  http://item.gmarket.co.kr/Item?goodscode=14016...   38500   30800
# 173  http://item.gmarket.co.kr/Item?goodscode=32076...           42900
# 174  http://item.gmarket.co.kr/Item?goodscode=13771...   38500   30800
# 175  http://item.gmarket.co.kr/Item?goodscode=13384...   63200   50560
# 176  http://item.gmarket.co.kr/Item?goodscode=14425...  133000   39900
# 177  http://item.gmarket.co.kr/Item?goodscode=21567...   19500    5900
# 178  http://item.gmarket.co.kr/Item?goodscode=92263...   16900   13900
# 179  http://item.gmarket.co.kr/Item?goodscode=11042...   19900   10000
# 180  http://item.gmarket.co.kr/Item?goodscode=22169...   18000    5900
# 181  http://item.gmarket.co.kr/Item?goodscode=11241...   22900   11900
# 182  http://item.gmarket.co.kr/Item?goodscode=99947...   22900    6900
# 183  http://item.gmarket.co.kr/Item?goodscode=93551...           21900
# 184  http://item.gmarket.co.kr/Item?goodscode=73072...   29800   16500
# 185  http://item.gmarket.co.kr/Item?goodscode=17111...   19600    5900
# 186  http://item.gmarket.co.kr/Item?goodscode=11478...   84100   64900
# 187  http://item.gmarket.co.kr/Item?goodscode=13852...   39900   36900
# 188  http://item.gmarket.co.kr/Item?goodscode=93212...   35200   20500
# 189  http://item.gmarket.co.kr/Item?goodscode=11167...   32900    9900
# 190  http://item.gmarket.co.kr/Item?goodscode=11646...   52520   39900
# 191  http://item.gmarket.co.kr/Item?goodscode=94573...   44800   13900
# 192  http://item.gmarket.co.kr/Item?goodscode=98297...   89600   26900
# 193  http://item.gmarket.co.kr/Item?goodscode=35330...   23000    7900
# 194  http://item.gmarket.co.kr/Item?goodscode=91419...   15130   13900
# 195  http://item.gmarket.co.kr/Item?goodscode=80977...   13500    9900
# 196  http://item.gmarket.co.kr/Item?goodscode=66931...   18900    6900
# 197  http://item.gmarket.co.kr/Item?goodscode=69106...   22000   10900
# 198  http://item.gmarket.co.kr/Item?goodscode=14496...           12400
# 199  http://item.gmarket.co.kr/Item?goodscode=14098...   32900    9900
#
#                                                  title
# 0                      2+1 여름 덧신 40켤레 골지 면 페이크삭스 발목 양말
# 1    (단독한정판매)캐리비안베이 종일권+자켓대여+에버랜드 오후 5시 이용권(7/21~8/...
# 2                  [롯데푸드]의성마늘프랑크 70gx20개/핫바/간식/소시지/소세지
# 3                              한정특가 절대 번지지 않는 붓펜 아이라이너
# 4                          초특가브랜드3단자동우산/아동/장우산/양산/돌답례품
# 5                    [속옷미인]잠옷/홈웨어/파자마/여성잠옷/선물/원피스/여름잠옷
# 6               [고스트리퍼블릭]후기검증 200% S/S 베스트 반팔티셔츠 M-XXL
# 7                                 쏭스타일 롱티.루즈핏.박스티.신상특가
# 8                       업그레이드 (1+1)원터치 애니멀 텀블러(보온.보냉병)
# 9                      [아디다스]아디다스 에스트로 신형입고 인기컬러 긴급재입고
# 10                         르까프 케이스위스 7부팬츠 반바지 티셔츠 가격다운
# 11                     [팸퍼스]팸퍼스 베이비드라이 팬티 기저귀 3팩 3~6단계
# 12                                블레스유 여름신상 린넨원피스/블라우스
# 13                 [아워홈]게살/새우/돼지고기/칠리/치킨/불고기볶음밥250g10봉
# 14                         시스터 여름신상 빅사이즈 원피스/롱티/투피스/팬츠
# 15                   (6/25특가) 에이핀 35cm 프리미엄 선풍기/리모컨 홍진
# 16                        단하루 역대급특가 투투 ~3XL/린넨/슬랙스/반바지
# 17                        붐붐-G단독특가상하복/세트/아동복/유아복/츄리닝세트
# 18                       25일_하루특가/ 남여 샌들/아쿠아슈즈/스니커즈/남성
# 19                           더그린 3겹 화장지 25m 30롤 x 2+1팩
# 20                        [루체]루체 블라우스세트/린넨가디건 4900~ 무배
# 21                     [에이블린]여름 신상 가득~ 린넨/티셔츠/원피스/빅사이즈
# 22                        삠뽀요/전상픔SALE 베이비 상하복 원피스 래쉬가드
# 23               [맥심]쿠폰가29900원~모카골드/화이트 340T/320T/커피믹스
# 24                             아디다스/나이키 가방/반팔티/반바지/슬리퍼
# 25                       (1+1/파격세일)전기세 절약 시원한 여름 대나무자리
# 26                          키스포/여름수영복시즌오프/복수구매할인/반바지/반
# 27                              종이컵 1000개 한박스(사업자반값상품)
# 28             [아몬드브리즈]쿠폰가12400 매일 아몬드브리즈 190ml 24팩/두유
# 29                           여름신상/쉬폰블라우스/티셔츠/셔츠/플라워모음전
# ..                                                 ...
# 170                     부산 멸균우유1000mlx10팩/서울우유/연세우유/우유
# 171                        (행사가)이지핏 프리미엄 안전문 플러스 유아 애견
# 172                    [나이키]선레이 프로텍트 2 (PS) 943826-001
# 173                      [군기저귀]18년 공식대리점 군기저귀 밴드3팩팬티3팩
# 174                    [나이키]선레이 프로텍트 2 (PS) 943828-001
# 175                 [나이키]런올데이 898464-404 898464-404 남성
# 176                  [에이치커넥트]본사직영 겨울 아우터 구매찬스/다운/패딩/코트
# 177                      스위트바니 여름신상 5900원~ 롱티셔츠/박스티/반팔
# 178                     [칠성사이다]칠성사이다 355mlx24캔 음료수 캔음료
# 179                [아카시아]무민 도마 2P세트 (대중) 원목주방용품 브랜드기획전
# 180                         국산/봄신상/아동/내복/내의/주니어/실내복/잠옷
# 181                      [스마트에코]스마트에코물티슈베이직100매리필형X20팩
# 182                         [송월타월]송월우산 프리미엄우산 39종 무료배송
# 183              [엑타코](단하루 3+1 무배)엑타코4400 휴대용선풍기 미니/핸디
# 184               [윈드피아]가정용 업소용 벽걸이 스탠드 휴대용 선풍기 WA-370
# 185                [디즈니]1+1 아동실내화 어린이 초등학생 신학기 유아 초등 봄
# 186                  [피스넷]끊김없는 완전무선 블루투스이어폰 피스넷 프리고 블랙
# 187                    [하기스]에어솔솔썸머팬티 5단계 남아 40P 2팩/기저귀
# 188                 [굽네몰]6월행사/굽네 닭가슴살 15+1팩/훈제/수비드/소세지
# 189                        드레스제이/신상원피스/55-88/빅사이즈/롱/루즈
# 190                  [피스넷]메탈 완전무선 블루투스이어폰 피스넷 프리스틱 그레이
# 191                [코리아나]앰플엔 단. 하루특가~앰플1+1/샤셰2매증정/물광피부
# 192                   [디즈니]디즈니 미키마우스 캐리어/밤비 푸 여행가방/케리어
# 193                     S~4XL 반팔티/티셔츠/남자/면티/남성/의류/티/반팔
# 194                 [아토세이프]참숯 습기매직싹 제습제 20개입/습기제거제/곰팡이
# 195                    칸타타 아이스커피 190mlx20팩/쟈뎅까페리얼/카페베네
# 196                             데일리샵 여름 티셔츠 신상/빅사이즈/반팔
# 197                        하리보 젤리 골드베렌980g 웰치스젤리 후르트텔라
# 198  (특전포토카드세트) 트와이스(TWICE) - SUMMER SPECIAL 2집 Sum...
# 199                       샌들 99균일가 플랫샌들 스트랩 웨지 슬리퍼 슬링백
#
# [200 rows x 4 columns]

# %%
# 빈 칸 채워넣기

is_nodata = df["o-price"] == ""
df["o-price"][is_nodata] = df["s-price"][is_nodata]

# %%
# 할인율 컬럼 추가

df["discount_rate"] = round((1 - df["s-price"].astype(int) / df["o-price"].astype(int)) * 100, 1)
df["discount_rate"] = df["discount_rate"].astype('str')
df["discount_rate"] += "%"
df["discount_rate"].tail()
# Out:
# 195    54.2%
# 196    69.7%
# 197    69.8%
# 198    68.2%
# 199    70.0%
# Name: discount_rate, dtype: object

# %%
driver.quit()

# %% [markdown]
# ### _네이버 메일 크롤링_
#
# - 네이버 페이지로 이동
# - 아이디 패스워드를 입력
# - 로그인 버튼을 클릭
# - 메일 페이지로 이동
# - 메일 페이지에서 메일 데이터 수집

# %%
main_url = "http://naver.com"
mail_url = "https://mail.naver.com"

# %%
# 네이버 페이지로 이동

driver = webdriver.Chrome()
driver.get(main_url)

# %%
# 아이디, 패스워드 입력

driver.find_element_by_css_selector("#id").send_keys("syh602")
driver.find_element_by_css_selector("#pw").send_keys("")

# %%
# 로그인 버튼 클릭

driver.find_element_by_css_selector(".btn_login > input[type=submit]").click()

# %%
# 메일 페이지로 이동

driver.get(mail_url)

# %%
mails = driver.find_elements_by_css_selector(".mailList > li")

# %%
for mail in mails[:10]:
    name = mail.find_element_by_css_selector(".name > a").text
    title = mail.find_element_by_css_selector(".mail_title").text
    print(name)
# Out:
# 네이버페이
# 쿠팡
# 경향하우징페어
# 케이팜 귀농귀촌 박람..
# syh602@gmail.com
# 운영사무국
# 청년유니온
# 밀알복지재단
# dothome
# 밀알복지재단

# %%
"https://mail.naver.com/?n=1529567449175&v=f#{"fClass":"list","oParameter":{"page":"2","sortField":1,"sortType":0,"folderSN":"0","type":"","isUnread":false,"viewMode":"conversation","startOffset":118,"pageSize4SeeMore":100}}"
# Out:
#   File "<ipython-input-139-6bb947555b47>", line 1
#     url2 = "https://mail.naver.com/?n=1529567449175&v=f#{"fClass":"list","oParameter":{"page":"2","sortField":1,"sortType":0,"folderSN":"0","type":"","isUnread":false,"viewMode":"conversation","startOffset":118,"pageSize4SeeMore":100}}"
#                                                                ^
# SyntaxError: invalid syntax

# %%
driver.quit()

# %% [markdown]
# ### _워드프레스 댓글 자동화_
#
# - https://
# - 2개의 계정, 2개의 메시지, 2개의 게시글에 총 8개의 댓글을 자동으로 작성
# - 게시물의 링크를 크롤링
# - 각 게시물로 가서 댓글 작성
#     - 댓글 작성 레이어 클릭
#     - 댓글 작성
#     - 이메일, 이름 추가
#     - 댓글 작성 버튼 클릭

# %%
url = "https://radajin661456067.wordpress.com/"
driver = webdriver.Chrome()
driver.get(url)

# %%
links = []
articles = driver.find_elements_by_css_selector("#main > article")

for article in articles:
    links.append(
        article.find_element_by_css_selector(".entry-title > a").get_attribute("href")
    )
links
# Out:
# ['https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/',
#  'https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/']

# %%
# 링크로 이동

driver.get(links[0])

# %%
# 스크롤 내리기

script = "window.scrollTo(0, 10000)"
driver.execute_script(script)

# %%
# 댓글창 클릭
driver.find_element_by_css_selector("#comment-form-comment").click()

# %%
# 댓글 내용 작성
driver.find_element_by_css_selector("#comment").send_keys("하나씩")

# %%
# 스크롤 내리기
script = "window.scrollTo(0, 10000)"
driver.execute_script(script)

# %%
# 이메일 이름 입력

driver.find_element_by_css_selector("#email").clear() #?
driver.find_element_by_css_selector("#email").send_keys("1234")
driver.find_element_by_css_selector("#author").clear()
driver.find_element_by_css_selector("#author").send_keys("1234")

# %%
# 댓글 작성 버튼 클릭
driver.find_element_by_css_selector("#comment-submit").click()

# %%
import time

# %%
def write_comment(driver, link, msg, email, name):
    driver.get(link)
    script = "window.scrollTo(1, 10000)"
    driver.execute_script(script)
    time.sleep(1)
    driver.find_element_by_css_selector("#comment-form-comment").click()
    time.sleep(1)
    driver.find_element_by_css_selector("#comment").send_keys("하나씩")
    time.sleep(1)
    driver.find_element_by_css_selector("#email").clear()
    driver.find_element_by_css_selector("#email").send_keys(email)
    driver.find_element_by_css_selector("#author").clear()
    driver.find_element_by_css_selector("#author").send_keys(name)

    driver.find_element_by_css_selector("#comment-submit").click()

# %%
users = [
    {"name":"sujin", "email":"jingjing"},
    {"name":"seokyeong", "email":"quartz"},
]

msgs = ["우리 존재 화이팅", "아자뵤오"]

# %%
for user in users:
    for msg in msgs:
        for link in links:
            print(user["name"], user["email"], msg, link)
            try:
                write_comment(driver, link, msg, user["email"], user["name"])
            except:
                print(user)
# Out:
# sujin jingjing 우리 존재 화이팅 https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/
# {'name': 'sujin', 'email': 'jingjing'}
# sujin jingjing 우리 존재 화이팅 https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/
# {'name': 'sujin', 'email': 'jingjing'}
# sujin jingjing 아자뵤오 https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/
# {'name': 'sujin', 'email': 'jingjing'}
# sujin jingjing 아자뵤오 https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/
# {'name': 'sujin', 'email': 'jingjing'}
# seokyeong quartz 우리 존재 화이팅 https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/
# {'name': 'seokyeong', 'email': 'quartz'}
# seokyeong quartz 우리 존재 화이팅 https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/
# {'name': 'seokyeong', 'email': 'quartz'}
# seokyeong quartz 아자뵤오 https://radajin661456067.wordpress.com/2018/06/21/%ed%85%8c%ec%8a%a4%ed%8a%b8/
# {'name': 'seokyeong', 'email': 'quartz'}
# seokyeong quartz 아자뵤오 https://radajin661456067.wordpress.com/2018/06/21/%ec%b2%ab-%eb%b2%88%ec%a7%b8-%eb%b8%94%eb%a1%9c%ea%b7%b8-%ea%b8%80/
# {'name': 'seokyeong', 'email': 'quartz'}

# %%
driver.quit()

# %% [markdown]
# ### _이미지 스크린샷_
#
# - youtube

# %%
import time
from selenium import webdriver
from PIL import Image as pil

# %%
url = "https://www.youtube.com/watch?v=9Ezsz6uOeq4"
driver = webdriver.Chrome()
driver.get(url)
time.sleep(1) # 로딩 속도에 따라서 스크린샷(파일)이 깨지는 상황을 방지하기 위해서.

# %%
# 이미지 스크린샷

# 스크린샷을 저장하는 코드 


for idx in range(1, 6):
    time.sleep(1)
    driver.save_screenshot("screenshot_"+str(idx)+".png")

# %%
driver.quit()

# %%
# 이미지 띄우기

pil_im = pil.open("screenshot_1.png")
print(pil_im.size)
pil_im
# Out:
# (1200, 719)
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1200x719 at 0x113807438>

# %%
url = "https://www.youtube.com/watch?v=SESuctdE9vM"
driver = webdriver.Chrome()
driver.get(url)

# %%
element = driver.find_element_by_css_selector("#player-container")
location = element.location
size = element.size
location, size
# Out:
# ({'x': 80, 'y': 80}, {'height': 480, 'width': 854})

# %%
driver.quit()

# %%
# top, button, left, right 값 출력

left = location['x']
top = location['y']
right = location['x'] + size['width']
button = location['y'] + size['height']

area = (left, top, right, button)
area
# Out:
# (80, 80, 934, 560)

# %%
# pillow 이미지 크롭

pil_im = pil.open("screenshot_2.png")
pil_im = pil_im.crop(area)
pil_im
# Out:
# <PIL.Image.Image image mode=RGBA size=854x480 at 0x112A2EBA8>

# %%
# pillow 이미지 저장

pil_im.save("cropped screenshot.png")

# %%
# 하단의 재생 영역 자르기

url = "https://www.youtube.com/watch?v=SESuctdE9vM"
driver = webdriver.Chrome()
driver.get(url)

element = driver.find_element_by_css_selector(".ytp-chrome-bottom")
location = element.location
size = element.size
location, size
# Out:
# ({'x': 79, 'y': 401}, {'height': 39, 'width': 616})

# %%
left = location['x']
top = location['y']
right = location['x'] + size['width']
button = location['y'] + size['height'] - 39

area = (left, top, right, button)
area
# Out:
# (79, 401, 695, 401)

# %%
driver.save_screenshot("screenshot00.png")
# Out:
# True

# %%
driver.quit()

# %%
# 실습2 : 이미지 스크린샷, 비전 API로 이미지 분석하기

# %%
# 썸네일

pil_im = pil.open("cropped screenshot.png")
pil_im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=854x480 at 0x1118E2DA0>

# %%
pil_im.thumbnail((300, 200))
pil_im.size
# Out:
# (300, 168)

# %%
pil_im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x168 at 0x1118E2DA0>

# %%
driver.quit()
